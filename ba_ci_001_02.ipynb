# %% [markdown]
# <p align="center">
# <img src="https://www.python.org/static/community_logos/python-powered-h-70x91.png?raw=true" width="100" height="">
# </p>

# %% [markdown]
#  # **<font color="#07a8ed">Preprocesamiento de los Datos - Codificación e imputaciones</font>**

# %% [markdown]
# ## **<font color="#07a8ed">Bibliotecas**

# %% [markdown]
# ### **<font color="#07a8ed">Para análisis de datos**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **<font color="#07a8ed">Para preprocesamiento de datos**

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder  ###  Codifique las etiquetas de destino con valores entre 0 y n_classes-1.

# %% [markdown]
# https://www.google.com/url?q=https%3A%2F%2Fscikit-learn.org%2Fstable%2Fmodules%2Fgenerated%2Fsklearn.preprocessing.LabelEncoder.html%23sklearn.preprocessing.LabelEncoder

# %%
from sklearn.impute import KNNImputer  ###Imputación para completar valores faltantes utilizando k-Vecinos más cercanos. Los valores faltantes de cada muestra se imputan utilizando el valor medio de n_neighborslos vecinos más cercanos

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html

# %% [markdown]
#  ## **<font color="#07a8ed">Obtención de los Datos</font>**

# %%
url = "https://raw.githubusercontent.com/cristiandarioortegayubro/BA/main/Datasets/banco.csv"

# %%
analisis = pd.read_csv(url, index_col=0)
analisis.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 4  unknown    5   may       198         1     -1         0  unknown      no

# %% [markdown]
#  ## **<font color="#07a8ed">Análisis Exploratorio de los Datos</font>**

# %%
###!pip install pandas-profiling --upgrade

# %%
###from ydata_profiling import ProfileReport

# %%
###ProfileReport(analisis)

# %% [markdown]
#  ## **<font color="#07a8ed">Reemplazo de "unknown"</font>**

# %%
analisis.replace({"unknown": None}, inplace=True)

# %%
analisis.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married       None      no     1506     yes   no
# 4   33          None    single       None      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#   contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0    None    5   may       261         1     -1         0     None      no
# 1    None    5   may       151         1     -1         0     None      no
# 2    None    5   may        76         1     -1         0     None      no
# 3    None    5   may        92         1     -1         0     None      no
# 4    None    5   may       198         1     -1         0     None      no
# 5    None    5   may       139         1     -1         0     None      no
# 6    None    5   may       217         1     -1         0     None      no
# 7    None    5   may       380         1     -1         0     None      no
# 8    None    5   may        50         1     -1         0     None      no
# 9    None    5   may        55         1     -1         0     None      no

# %%
analisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        44923 non-null  object
#  2   marital    45211 non-null  object
#  3   education  43354 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    32191 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   8252 non-null   object
#  16  deposit    45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 6.2+ MB

# %%
analisis.isnull().sum().sort_values(ascending=False)
# Out:
# poutcome     36959
# contact      13020
# education     1857
# job            288
# month            0
# previous         0
# pdays            0
# campaign         0
# duration         0
# age              0
# day              0
# loan             0
# housing          0
# balance          0
# default          0
# marital          0
# deposit          0
# dtype: int64

# %% [markdown]
# ## **<font color="#07a8ed">Codificación de variables categóricas</font>**

# %%
convertir = LabelEncoder()

# %%
analisis.insert(2,column="numjob",value=convertir.fit_transform(analisis.job))
analisis.insert(4,column="nummarital",value=convertir.fit_transform(analisis.marital))
analisis.insert(6,column="numeducation",value=convertir.fit_transform(analisis.education))
analisis.insert(8,column="numdefault",value=convertir.fit_transform(analisis.default))
analisis.insert(11,column="numhousing",value=convertir.fit_transform(analisis.housing))
analisis.insert(13,column="numloan",value=convertir.fit_transform(analisis.loan))
analisis.insert(15,column="numcontact",value=convertir.fit_transform(analisis.contact))
analisis.insert(23,column="numpoutcome",value=convertir.fit_transform(analisis.poutcome))

# %%
def mes(month):
  if month == "jan":
    return int("1")
  elif month == "feb":
    return int("2")
  elif month == "mar":
    return int("3")
  elif month == "apr":
    return int("4")
  elif month == "may":
    return int("5")
  elif month == "jun":
    return int("6")
  elif month == "jul":
    return int("7")
  elif month == "aug":
    return int("8")
  elif month == "sep":
    return int("9")
  elif month == "oct":
    return int("10")
  elif month == "nov":
    return int("11")
  else:
    return int("12")

# %%
analisis.month = analisis.month.apply(mes)

# %% [markdown]
#  ## **<font color="#07a8ed">Imputación de valores faltantes</font>**

# %%
analisis.head()
# Out:
#    age           job  numjob  marital  nummarital  education  numeducation  \
# 0   58    management       4  married           1   tertiary             2
# 1   44    technician       9   single           2  secondary             1
# 2   33  entrepreneur       2  married           1  secondary             1
# 3   47   blue-collar       1  married           1       None             3
# 4   33          None      11   single           2       None             3
#
#   default  numdefault  balance  ... numcontact  day month  duration campaign  \
# 0      no           0     2143  ...          2    5     5       261        1
# 1      no           0       29  ...          2    5     5       151        1
# 2      no           0        2  ...          2    5     5        76        1
# 3      no           0     1506  ...          2    5     5        92        1
# 4      no           0        1  ...          2    5     5       198        1
#
#    pdays  previous  poutcome  numpoutcome  deposit
# 0     -1         0      None            3       no
# 1     -1         0      None            3       no
# 2     -1         0      None            3       no
# 3     -1         0      None            3       no
# 4     -1         0      None            3       no
#
# [5 rows x 25 columns]

# %%
analisis.job[4]

# %%
analisis.numjob[4]
# Out:
# 11

# %%
imputacion = KNNImputer(n_neighbors=3, missing_values=11, weights="uniform")

# %% [markdown]
# ### n_neighbors = Número de muestras vecinas a utilizar para la imputación.
# ### missing_values = El marcador de posición para los valores faltantes.
# ### weights = 'uniform': ponderaciones uniformes. Todos los puntos de cada vecindario tienen la misma ponderación.

# %%
analisis.numjob = imputacion.fit_transform(analisis[["numjob"]])

# %%
analisis.numjob = round(analisis.numjob,3)

# %%
analisis.numjob[4]  ### valor fila 4
# Out:
# 4.297

# %%
analisis.head()
# Out:
#    age           job  numjob  marital  nummarital  education  numeducation  \
# 0   58    management   4.000  married           1   tertiary             2
# 1   44    technician   9.000   single           2  secondary             1
# 2   33  entrepreneur   2.000  married           1  secondary             1
# 3   47   blue-collar   1.000  married           1       None             3
# 4   33          None   4.297   single           2       None             3
#
#   default  numdefault  balance  ... numcontact  day month  duration campaign  \
# 0      no           0     2143  ...          2    5     5       261        1
# 1      no           0       29  ...          2    5     5       151        1
# 2      no           0        2  ...          2    5     5        76        1
# 3      no           0     1506  ...          2    5     5        92        1
# 4      no           0        1  ...          2    5     5       198        1
#
#    pdays  previous  poutcome  numpoutcome  deposit
# 0     -1         0      None            3       no
# 1     -1         0      None            3       no
# 2     -1         0      None            3       no
# 3     -1         0      None            3       no
# 4     -1         0      None            3       no
#
# [5 rows x 25 columns]

# %%
analisis.job.value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# Name: count, dtype: int64

# %%
analisis.numjob.value_counts()
# Out:
# numjob
# 1.000     9732
# 4.000     9458
# 9.000     7597
# 0.000     5171
# 7.000     4154
# 5.000     2264
# 6.000     1579
# 2.000     1487
# 10.000    1303
# 3.000     1240
# 8.000      938
# 4.297      288
# Name: count, dtype: int64
