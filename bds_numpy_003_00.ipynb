# %% [markdown]
# <p align="center">
# <img src="https://numpy.org/images/logo.svg" width="80" height="">
# </p>

# %% [markdown]
# https://numpy.org

# %% [markdown]
#  # **<font color="RoyalBlue">Generación de muestras aleatorias</font>**

# %% [markdown]
# <p align="justify">
# ✅ La generación de números aleatorios es fundamental en estadística y simulación de experimentos. <code>NumPy</code> proporciona una amplia gama de funciones en el módulo <code>numpy.random</code> para generar muestras aleatorias de diferentes distribuciones.
# <br><br>
# 👀 A continuación, se presentan algunas distribuciones comunes y ejemplos de su aplicación:

# %% [markdown]
# <p align="justify"> 👀 Por convención, de esta manera se importa <code>Numpy</code>:  </p>

# %%
import numpy as np

# %%
import plotly.express as px

# %% [markdown]
#  ## **<font color="RoyalBlue">Distribución uniforme</font>**

# %% [markdown]
# <p align="justify">
# ✅ La distribución uniforme genera números aleatorios en un rango especificado con igual probabilidad. Esto puede ser útil para simular eventos donde todas las posibilidades son igualmente probables.
# <br><br>
# Por ejemplo, supongamos que queremos simular el lanzamiento de un dado:
#
# ```python
# # Simular el lanzamiento de un dado
# dado = np.random.randint(1, 7)  # Números aleatorios del 1 al 6
#
# print("Resultado del lanzamiento del dado:", dado)
# ```

# %%
# Simular el lanzamiento de un dado
dado = np.random.randint(1, 7)  # Números aleatorios del 1 al 6
dado
# Out:
# 6

# %%
dado = np.random.randint(1, 7)
dado
# Out:
# 6

# %%
dado = np.random.randint(1, 7)
dado
# Out:
# 5

# %% [markdown]
# <p align="justify">
# 👀 Otro ejemplo, supongamos que queremos modelar la distribución de tiempos de espera de los clientes en una tienda, donde los clientes pueden llegar en cualquier momento dentro de un intervalo de tiempo específico.

# %%
# Generar datos de tiempos de espera de los clientes (distribución uniforme)
tiempos_espera = np.random.uniform(low=0, high=30, size=1000)  # Tiempos de espera en minutos, de 0 a 30 minutos

# %%
px.histogram(x=tiempos_espera,
             title="Distribución Uniforme de tiempos de espera de clientes",
             labels={"x":"Tiempo de Espera (minutos)"},
             template="gridon").update_layout(bargap=0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="32d73b88-fbf5-480c-b7bc-8957efcebdc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32d73b88-fbf5-480c-b7bc-8957efcebdc3")) {                    Plotly.newPlot(                        "32d73b88-fbf5-480c-b7bc-8957efcebdc3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Tiempo de Espera (minutos)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[14.156180437054687,20.306614262994362,7.367394118611488,23.33266190428874,0.8773841801371762,5.55003707181446,5.056071905283327,15.762193070456991,0.5469633501774662,3.917223135032396,6.7286231304918775,4.337863616255521,11.82087116298902,6.943124174699275,6.576463969070145,16.436680280622184,5.511013437211776,27.312970616982767,20.099034488719184,13.191203706957099,5.249717296530051,15.18064852036942,25.016094983511646,20.64377378712287,24.105189621312235,26.217159448850484,3.5288662077670283,18.119852410699153,29.44067736350691,24.953037546087295,19.340361136788523,16.862330047245067,6.68003256174072,1.2860371563365924,13.054732435943068,16.44369072328794,2.9142679342809643,29.347888651053278,6.268056560411287,2.2425687079558045,18.93597317990311,8.674713869023314,20.33772968766592,26.248405576895973,4.79981892722987,20.33126065352188,26.46427266366822,17.00534413170798,3.131701070294619,15.162767473846273
"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Ingresos anuales"}},"yaxis":{"anchor":"x","domain":[0.0,1.0]},"legend":{"tracegroupgap":0},"title":{"text":"Distribuci\u00f3n ingresos anuales de empleados"},"boxmode":"group"},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('363b836f-32fe-4ccf-8e22-f62da3b53e3a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %%
px.ecdf(x=ingresos_anuales,
        template="gridon",
        title = "Función de distribución acumulada")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="253308f0-39a8-49f0-b49f-fa8a22276602" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("253308f0-39a8-49f0-b49f-fa8a22276602")) {                    Plotly.newPlot(                        "253308f0-39a8-49f0-b49f-fa8a22276602",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eprobability=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"dash":"solid","shape":"hv"},"marker":{"color":"#1F77B4","symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[70565.94,72199.79,74201.64,76616.35,77180.7,77894.41,78273.74,78537.63,80471.12,80697.62,82150.02,82431.73,82601.03,83130.38,83715.05,85129.37,85458.03,85658.63,85957.01,86692.8,86719.21,87308.53,87536.67,88147.82,88405.03,88783.25,89198.19,89215.83,89365.21,89382.47,89567.28,89691.06,90186.16,90648.09,90719.46,93099.85,93600.37,93629.34,94200.31,94904.67,95651.51,96278.0,96360.63,96846.56,97367.53,98006.76,98393.8,99741.49,100103.49,101622.64,102180.72,103296.58,103364.57,103510.82,105210.13,105347.08,105487.53,106078.34,108038.62,111475.04],"xaxis":"x","y":[0.016666666666666666,0.03333333333333333,0.05,0.06666666666666667,0.08333333333333333,0.1,0.11666666666666667,0.13333333333333333,0.15,0.16666666666666666,0.18333333333333332,0.2,0.21666666666666667,0.23333333333333334,0.25,0.26666666666666666,0.2833333333333333,0.3,0.31666666666666665,0.3333333333333333,0.35,0.36666666666666664,0.38333333333333336,0.4,0.4166666666666667,0.43333333333333335,0.45,0.4666666666666667,0.48333333333333334,0.5,0.5166666666666667,0.5333333333333333,0.55,0.5666666666666667,0.5833333333333334,0.6,0.6166666666666667,0.6333333333333333,0.65,0.6666666666666666,0.6833333333333333,0.7,0.7166666666666667,0.7333333333333333,0.75,0.7666666666666667,0.7833333333333333,0.8,0.8166666666666667,0.8333333333333334,0.85,0.8666666666666667,0.8833333333333333,0.9,0.9166666666666666,0.9333333333333333,0.95,0.9666666666666667,0.9833333333333333,1.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"x"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"probability"},"rangemode":"tozero"},"legend":{"tracegroupgap":0},"title":{"text":"Funci\u00f3n de distribuci\u00f3n acumulada"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('253308f0-39a8-49f0-b49f-fa8a22276602');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# <p align="justify">
# Otro ejemplo, supongamos que queremos modelar la distribución de la altura de los clientes de una tienda de camisas para determinar el tamaño promedio que deberíamos tener en stock....

# %%
# Generar datos de altura de los clientes (distribución normal)
altura_clientes = np.random.normal(loc=170, scale=10, size=1000)

# %%
int(1+np.log2(1000))
# Out:
# 10

# %%
px.histogram(x=altura_clientes,
             nbins=10,
             title="Distribución de altura de los clientes",
             labels={"x":"Altura (cm)"},
             template="gridon").update_layout(bargap=0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a2fd6fd-d6fb-4a93-8afe-fdedd4ef9930" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a2fd6fd-d6fb-4a93-8afe-fdedd4ef9930")) {                    Plotly.newPlot(                        "3a2fd6fd-d6fb-4a93-8afe-fdedd4ef9930",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"
#
# ```python
# # Simular el número de clientes que compran un producto en una tienda en línea durante una hora
# num_clientes = np.random.binomial(n=100, p=0.1, size=1)
#
# # 'n' es el número de ensayos, 'p' es la probabilidad de éxito y 'size' es el tamaño de la muestra
#
# print("Número de clientes que compran un producto:", num_clientes)
# ```

# %%
# Simular el número de clientes que compran un producto en una tienda en línea durante una hora
num_clientes = np.random.binomial(n=100, p=0.1, size=1)
num_clientes
# Out:
# array([5])

# %% [markdown]
# <p align="justify">
# 👀 Otro ejemplo, supongamos que queremos modelar la probabilidad de que un cliente realice una compra en una tienda en línea, donde la probabilidad de compra es del 30% y realizamos 100 intentos de compra...

# %%
# Simular el número de clientes que compran un producto en una tienda en línea
num_clientes_compran = np.random.binomial(n=100, p=0.3, size=800)

# %%
int(1+np.log2(800))
# Out:
# 10

# %%
px.histogram(x=num_clientes_compran,
             nbins=10,
             title="Número de clientes que compran un producto",
             labels={"x":"Número de Clientes que Compran"},
             template="gridon").update_layout(bargap=0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d46b7f2f-d1a0-4823-8f98-1d2eb9b88bf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d46b7f2f-d1a0-4823-8f98-1d2eb9b88bf1")) {                    Plotly.newPlot(                        "d46b7f2f-d1a0-4823-8f98-1d2eb9b88bf1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"N\u00famero de Clientes que Compran=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[30,26,34,23,28,24,27,28,28,34,37,29,23,26,33,30,32,33,35,31,32,29,37,24,25,35,29,30,27,32,25,35,27,33,30,36,32,25,27,20,26,29,26,35,30,26,27,26,25,19,28,26,33,43,31,31,31,30,25,32,14,29,32,31,32,36,26,30,37,36,31,28,28,32,29,33,31,33,31,28,26,25,24,37,28,32,28,35,30,27,30,30,34,21,23,33,32,27,31,37,31,28,24,27,30,32,30,25,18,31,28,33,29,26,30,30,31,39,32,29,31,36,31,32,23,27,36,37,37,38,30,24,34,37,31,34,33,32,29,27,36,30,33,30,26,32,27,27,29,36,29,29,22,29,32,31,35,33,27,40,35,28,31,29,23,29,33,32,17,29,26,27,30,32,35,30,20,30,29,27,27,24,27,30,28,31,24,25,36,29,27,36,32,30,31,33,20,34,34,33,31,27,28,36,30,33,35,22,32,30,30,31,31,31,35,35,27,25,27,37,31,35,34,37,27,30,28,37,33,33,26,33,28,35,33,27,27,38,30,29,28,30,30,32,27,32,30,28,29,27,30,28,36,28,24,35,21,36,25,31,31,29,38,35,34,27,25,30,37,28,32,28,24,29,28,27,27,27,30,26,28,28,26,31,29,27,35,28,32,34,30,33,34,26,28,26,31,28,31,32,28,37,25,29,34,25,25,37,25,29,37,28,28,26,27,26,22,27,35,34,29,28,33,32,22,32,34,35,36,28,32,28,36,28,21,33,38,29,30,31,29,32,30,26,24,29,36,26,23,28,28,36,30,29,39,28,35,30,28,27,31,37,29,29,27,29,33,40,34,33,35,24,35,29,27,32,35,37,30,26,33,33,25,31,26,29,34,38,27,24,33,23,27,29,25,37,32,32,26,28,31,30,30,30,31,28,35,27,36,25,34,33,33,33,27,29,32,24,38,30,31,30,30,23,30,28,32,28,28,29,30,32,32,31,22,29,37,39,28,26,26,33,31,32,33,27,27,40,31,39,37
37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,38,39,39,39,39,39,39,39,39,40,40,40,40,40,41,41,41,41,42,43,43,45],"xaxis":"x","y":[0.00125,0.0025,0.00375,0.005,0.00625,0.0075,0.00875,0.01,0.01125,0.0125,0.01375,0.015,0.01625,0.0175,0.01875,0.02,0.02125,0.0225,0.02375,0.025,0.02625,0.0275,0.02875,0.03,0.03125,0.0325,0.03375,0.035,0.03625,0.0375,0.03875,0.04,0.04125,0.0425,0.04375,0.045,0.04625,0.0475,0.04875,0.05,0.05125,0.0525,0.05375,0.055,0.05625,0.0575,0.05875,0.06,0.06125,0.0625,0.06375,0.065,0.06625,0.0675,0.06875,0.07,0.07125,0.0725,0.07375,0.075,0.07625,0.0775,0.07875,0.08,0.08125,0.0825,0.08375,0.085,0.08625,0.0875,0.08875,0.09,0.09125,0.0925,0.09375,0.095,0.09625,0.0975,0.09875,0.1,0.10125,0.1025,0.10375,0.105,0.10625,0.1075,0.10875,0.11,0.11125,0.1125,0.11375,0.115,0.11625,0.1175,0.11875,0.12,0.12125,0.1225,0.12375,0.125,0.12625,0.1275,0.12875,0.13,0.13125,0.1325 ...

# %% [markdown]
#  ## **<font color="RoyalBlue">Distribución de Poisson</font>**

# %% [markdown]
# <p align="justify">
# ✅ La distribución de Poisson modela el número de eventos que ocurren en un intervalo de tiempo o espacio fijo, dado que los eventos ocurren a una tasa constante e independientemente del tiempo o espacio.
# <br><br>
# Por ejemplo, supongamos que queremos simular el número de llamadas de servicio al cliente recibidas en una hora`
#
# ```python
# # Simular el número de llamadas de servicio al cliente recibidas en una hora
# num_llamadas = np.random.poisson(lam=10, size=1)
#
# # 'lam' es la tasa de eventos y 'size' es el tamaño de la muestra
#
# print("Número de llamadas de servicio al cliente:", num_llamadas)
# ```

# %%
# Simular el número de llamadas de servicio al cliente recibidas en una hora
num_llamadas = np.random.poisson(lam=10, size=1)
num_llamadas
# Out:
# array([15])

# %% [markdown]
# <p align="justify">
# 👀 Otro ejemplo, supongamos que queremos modelar el número de llamadas de servicio al cliente recibidas en una hora, donde recibimos un promedio de 10 llamadas por hora.

# %%
# Simular el número de llamadas de servicio al cliente recibidas en una hora
num_llamadas = np.random.poisson(lam=10, size=1000)

# %%
int(1+np.log2(1000))
# Out:
# 10

# %%
px.histogram(x=num_llamadas,
             nbins=10,
             title="Distribución de Poisson de llamadas de Servicio al Cliente",
             labels={"x":"Número de llamadas"},
             template="gridon").update_layout(bargap=0.2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="425e1401-9a7c-4495-b737-fcf5a8766281" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("425e1401-9a7c-4495-b737-fcf5a8766281")) {                    Plotly.newPlot(                        "425e1401-9a7c-4495-b737-fcf5a8766281",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"N\u00famero de llamadas=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[7,5,12,8,14,6,9,10,9,11,10,7,11,14,10,13,12,9,5,13,9,9,9,10,9,9,14,12,6,13,10,7,16,9,11,11,5,13,14,10,12,12,13,8,11,10,6,7,4,11,14,7,7,12,7,8,16,6,9,11,9,18,18,17,11,13,15,11,8,9,8,8,13,12,7,9,6,4,11,11,7,4,7,7,7,11,11,7,8,6,7,11,13,9,9,21,
16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,18,18,18,18,18,18,18,18,19,19,19,19,19,21,21,21,23,23,26],"xaxis":"x","y":[0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015,0.016,0.017,0.018,0.019,0.02,0.021,0.022,0.023,0.024,0.025,0.026,0.027,0.028,0.029,0.03,0.031,0.032,0.033,0.034,0.035,0.036,0.037,0.038,0.039,0.04,0.041,0.042,0.043,0.044,0.045,0.046,0.047,0.048,0.049,0.05,0.051,0.052,0.053,0.054,0.055,0.056,0.057,0.058,0.059,0.06,0.061,0.062,0.063,0.064,0.065,0.066,0.067,0.068,0.069,0.07,0.071,0.072,0.073,0.074,0.075,0.076,0.077,0.078,0.079,0.08,0.081,0.082,0.083,0.084,0.085,0.086,0.087,0.088,0.089,0.09,0.091,0.092,0.093,0.094,0.095,0.096,0.097,0.098, ...

# %% [markdown]
#  # **<font color="RoyalBlue">Cálculo de medidas de tendencia central y dispersión</font>**

# %% [markdown]
# <p align="justify">
# ✅ Las medidas de tendencia central y dispersión son fundamentales en estadística para resumir y comprender la distribución de los datos. NumPy proporciona funciones para calcular estas medidas de manera eficiente.
# <br><br>
# A continuación, se presenta cómo calcular y utilizar estas medidas en contextos empresariales:
# </p>

# %% [markdown]
#  ## **<font color="RoyalBlue">Medidas de tendencia central</font>**

# %% [markdown]
#  ### **<font color="RoyalBlue">Media (Promedio)</font>**

# %% [markdown]
# <p align="justify">
# ✅ La media es la suma de todos los valores dividida por el número de valores. Es útil para calcular el valor promedio de un conjunto de datos. Por ejemplo, para calcular el promedio de las ventas mensuales de una empresa...
#
# ```python
# # Ventas mensuales de una empresa en miles de dólares
# ventas_mensuales = np.array([100, 120, 110, 130, 140])
#
# # Calcular la media de las ventas mensuales
# media_ventas = np.mean(ventas_mensuales)
#
# print("Media de las ventas mensuales:", media_ventas)
# ```

# %%
# Ventas mensuales de una empresa en miles de dólares
ventas_mensuales = np.array([100, 120, 110, 130, 140])
ventas_mensuales
# Out:
# array([100, 120, 110, 130, 140])

# %%
# Calcular la media de las ventas mensuales
media_ventas = np.mean(ventas_mensuales)
media_ventas
# Out:
# 120.0

# %% [markdown]
#  ### **<font color="RoyalBlue">Mediana</font>**

# %% [markdown]
# <p align="justify">
# ✅ La mediana es el valor que se encuentra en el centro de un conjunto de datos ordenados. Es útil cuando los datos están sesgados o tienen valores atípicos. Por ejemplo, para calcular la mediana de los ingresos anuales de una muestra de empleados...
#
# ```python
# # Ingresos anuales de una muestra de empleados en miles de dólares
# ingresos_anuales = np.array([40000, 50000, 60000, 70000, 80000])
#
# # Calcular la mediana de los ingresos anuales
# mediana_ingresos = np.median(ingresos_anuales)
#
# print("Mediana de los ingresos anuales:", mediana_ingresos)
# ```

# %%
# Ingresos anuales de una muestra de empleados en miles de dólares
ingresos_anuales = np.array([40000, 50000, 60000, 70000, 80000, 90000, 100000])
ingresos_anuales
# Out:
# array([ 40000,  50000,  60000,  70000,  80000,  90000, 100000])

# %%
# Calcular la mediana de los ingresos anuales
mediana_ingresos = np.median(ingresos_anuales)
mediana_ingresos
# Out:
# 70000.0

# %% [markdown]
#  ### **<font color="RoyalBlue">Moda</font>**

# %% [markdown]
# <p align="justify">
# ✅ La moda es el valor que aparece con mayor frecuencia en un conjunto de datos. Es útil para identificar patrones de comportamiento. Por ejemplo, para calcular la moda de los productos más vendidos en una tienda:
#
# ```python
# # Número de ventas diarias de diferentes productos en una tienda
# ventas_diarias = np.array([20, 30, 25, 25, 40, 30, 30, 25])
#
# # Calcular la moda de las ventas diarias
# moda_ventas = np.argmax(np.bincount(ventas_diarias))
#
# print("Producto más vendido (moda):", moda_ventas)
# ```

# %%
# Número de ventas diarias de diferentes productos en una tienda
ventas_diarias = np.array([20, 30, 25, 25, 40, 30, 30, 25, 40, 25, 30, 30, 45, 45, 30])
ventas_diarias
# Out:
# array([20, 30, 25, 25, 40, 30, 30, 25, 40, 25, 30, 30, 45, 45, 30])

# %%
# Calcular la moda de las ventas diarias
moda_ventas = np.argmax(np.bincount(ventas_diarias))
moda_ventas
# Out:
# 30

# %% [markdown]
#  ## **<font color="RoyalBlue">Medidas de dispersión</font>**

# %% [markdown]
#  ### **<font color="RoyalBlue">Varianza</font>**

# %% [markdown]
# <p align="justify">
# ✅ La varianza mide la dispersión de los datos con respecto a la media. Es útil para comprender la dispersión de los datos. Por ejemplo, para calcular la varianza de los tiempos de entrega de los pedidos de una empresa:
#
# ```python
# # Tiempos de entrega de los pedidos en días
# tiempos_entrega = np.array([2, 3, 2, 4, 3, 5, 2])
#
# # Calcular la varianza de los tiempos de entrega
# varianza_tiempos_entrega = np.var(tiempos_entrega)
#
# print("Varianza de los tiempos de entrega:", varianza_tiempos_entrega)
# ```

# %%
# Tiempos de entrega de los pedidos en días
tiempos_entrega = np.array([2, 3, 2, 4, 3, 5, 2, 5, 3, 6, 3, 2, 5, 4])
tiempos_entrega
# Out:
# array([2, 3, 2, 4, 3, 5, 2, 5, 3, 6, 3, 2, 5, 4])

# %%
# Calcular la varianza de los tiempos de entrega
varianza_tiempos_entrega = np.var(tiempos_entrega)
varianza_tiempos_entrega.round(2)
# Out:
# 1.68

# %% [markdown]
#  ### **<font color="RoyalBlue">Desviación estándar</font>**

# %% [markdown]
# <p align="justify">
# ✅ La desviación estándar es la raíz cuadrada de la varianza. Proporciona una medida de dispersión en la misma unidad que los datos originales. Por ejemplo, para calcular la desviación estándar de los precios de los productos en una tienda...
#
# ```python
# # Precios de los productos en una tienda en dólares
# precios_productos = np.array([20, 25, 30, 35, 40])
#
# # Calcular la desviación estándar de los precios de los productos
# desviacion_precios = np.std(precios_productos)
#
# print("Desviación estándar de los precios de los productos:", desviacion_precios)
# ```

# %%
# Precios de los productos en una tienda en dólares
precios_productos = np.array([20, 25, 30, 35, 40, 35, 40, 20])
precios_productos
# Out:
# array([20, 25, 30, 35, 40, 35, 40, 20])

# %%
# Calcular la desviación estándar de los precios de los productos
desviacion_precios = np.std(precios_productos)
desviacion_precios.round(2)
# Out:
# 7.68

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="RoyalBlue">
# Hemos llegado al final de nuestro colab, a seguir codeando en NumPy...
# </font>
# </p>
