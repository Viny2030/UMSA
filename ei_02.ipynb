# %% [markdown]
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20Statsmodels.png?raw=true" width="280">
# </p>

# %% [markdown]
# # **<font color="#07a8ed">Estadística inferencial con Python**

# %% [markdown]
# ## **<font color="#07a8ed">Bibliotecas**

# %% [markdown]
# ### **<font color="#07a8ed">Para análisis de datos**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### **<font color="#07a8ed">Para gráficos**

# %%
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### **<font color="#07a8ed">Para modelado**

# %% [markdown]
# #### **<font color="#07a8ed">Con Scikit-learn**

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.feature_selection import RFE

# %% [markdown]
# #### **<font color="#07a8ed">Con Statsmodels**

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ## **<font color="#07a8ed">Conjunto de Datos**

# %%
url = "https://raw.githubusercontent.com/cristiandarioortegayubro/BA/main/Datasets/publicidad_multiple.csv"

# %%
datos = pd.read_csv(url, index_col = 0)

# %%
datos.head(10)
# Out:
#    ventas  radio    tv  periodico
# 0   230.1   37.8  69.2       22.1
# 1    44.5   39.3  45.1       10.4
# 2    17.2   45.9  69.3        9.3
# 3   151.5   41.3  58.5       18.5
# 4   180.8   10.8  58.4       12.9
# 5     8.7   48.9  75.0        7.2
# 6    57.5   32.8  23.5       11.8
# 7   120.2   19.6  11.6       13.2
# 8     8.6    2.1   1.0        4.8
# 9   199.8    2.6  21.2       10.6

# %% [markdown]
# <p align="justify">
# Supóngase que el departamento de ventas de una empresa quiere estudiar la influencia que tiene la publicidad a través de distintos canales sobre el número de ventas de un producto. Se dispone de un conjunto de datos que contiene los ingresos (en millones) conseguido por ventas en 200 regiones, así como la cantidad de presupuesto, también en millones, destinado a anuncios por radio, TV y periódicos en cada una de ellas.

# %%
X = datos[["radio","tv","periodico"]]
y = datos[["ventas"]]

# %% [markdown]
# ### **<font color="#07a8ed">Gráfico de distribución para cada variable**

# %%
variables = datos.columns.tolist()
variables
# Out:
# ['ventas', 'radio', 'tv', 'periodico']

# %%
for i in variables:
  fig = px.histogram(datos,
                     x = i,
                     template = "gridon",
                     marginal= "box",
                     title = i).update_layout(bargap=0.2)
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32c9e7fb-d12a-4a9b-a02b-3645c1785463" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32c9e7fb-d12a-4a9b-a02b-3645c1785463")) {                    Plotly.newPlot(                        "32c9e7fb-d12a-4a9b-a02b-3645c1785463",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ventas=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[230.1,44.5,17.2,151.5,180.8,8.7,57.5,120.2,8.6,199.8,66.1,214.7,23.8,97.5,204.1,195.4,67.8,281.4,69.2,147.3,218.4,237.4,13.2,228.3,62.3,262.9,142.9,240.1,248.8,70.6,292.9,112.9,97.2,265.6,95.7,290.7,266.9,74.7,43.1,228.0,202.5,177.0,293.6,206.9,25.1,175.1,89.7,239.9,227.2,66.9,199.8,100.4,216.4,182.6,262.7,198.9,7.3,136.2,210.8,210.7,53.5,261.3,239.3,102.7,131.1,69.0,31.5,139.3,237.4,216.8,199.1,109.8,26.8,129.4,213.4,16.9,27.5,120.5,5.4,116.0,76.4,239.8,75.3,68.4,213.5,193.2,76.3,110.7,88.3,109.8,134.3,28.6,217.7,250.9,107.4,163.3,197.6,184.9,289.7,135.2,222.4,296.4,280.2,187.9,238.2,137.9,25.0,90.4,13.1,255.4,225.8,241.7,175.7,209.6,78.2,75.1,139.2,76.4,125.7,19.4,141.3,18.8,224.0,123.1,229.5,87.2,7.8,80.2,220.3,59.6,0.7,265.2,8.4,219.8,36.9,48.3,25.6,273.7,43.0,184.9,73.4,193.7,220.5,104.6,96.2,140.3,240.1,243.2,38.0,44.7,280.7,121.0,197.6,171.3,187.8,4.1,93.9,149.8,11.7,131.7,172.5,85.7,188.4,163.5,117.2,234.5,17.9,206.8,215.4,284.3,50.0,164.5,19.6,168.4,222.4,276.9,248.4,170.2,276.7,165.6,156.6,218.5,56.2,287.6,253.8,205.0,139.5,191.1,286.0,18.7,39.5,75.5,17.2,166.8,149.7,38.2,94.2,177.0,283.6,232.1],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","hovertemplate":"ventas=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[230.1,44.5,17.2,151.5,180.8,8.7,57.5,120.2
}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('d849c847-8a0e-47dc-94ec-f2efdcd6d37a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ## **<font color="#07a8ed">MODELO 1: todas las variables y todos los datos**

# %% [markdown]
# **<font color="#07a8ed">Con statsmodels formula:**

# %%
datos.head(2)
# Out:
#    ventas  radio    tv  periodico
# 0   230.1   37.8  69.2       22.1
# 1    44.5   39.3  45.1       10.4

# %%
modelo_f = smf.ols(formula="ventas~radio+tv+periodico", data=datos)
modelo_f = modelo_f.fit()

# %%
print(modelo_f.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ventas   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     360.8
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           1.61e-79
# Time:                        15:10:32   Log-Likelihood:                -986.30
# No. Observations:                 200   AIC:                             1981.
# Df Residuals:                     196   BIC:                             1994.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -33.2885      7.172     -4.641      0.000     -47.433     -19.144
# radio         -3.4496      0.206    -16.736      0.000      -3.856      -3.043
# tv             0.0450      0.118      0.382      0.703      -0.188       0.278
# periodico     18.4850      0.563     32.809      0.000      17.374      19.596
# ==============================================================================
# Omnibus:                       29.211   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.239
# Skew:                           0.884   Prob(JB):                     1.83e-09
# Kurtosis:                       4.305   Cond. No.                         139.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <p align="justify">
# El modelo con todas las variables introducidas como predictores tiene un $𝑅^2$  alto (0.847), es capaz de explicar el 84.7% de la variabilidad observada en las ventas.
# <br><br>
# F estadísitco grande (F-statistic =	360.8) y p-valor asociado extremadamente pequeño (Prob (F-statistic) = 1.61e-79), el modelo en su conjunto es estadísticamente significativo.
# <br><br>
# La variable explicativa tv no es estadísticamente significativa (p-valor = 0.703), por lo cual armaremos un nuevo modelo (<b>Modelo 2</b>) que no la incluya.

# %%
datos.corr()  ### analizamos las correlaciones
# Out:
#              ventas     radio        tv  periodico
# ventas     1.000000  0.054809  0.056648   0.782224
# radio      0.054809  1.000000  0.354104   0.576223
# tv         0.056648  0.354104  1.000000   0.228299
# periodico  0.782224  0.576223  0.228299   1.000000

# %% [markdown]
# **<font color="#07a8ed">Con statsmodels api:**

# %%
X.head(2)
# Out:
#    radio    tv  periodico
# 0   37.8  69.2       22.1
# 1   39.3  45.1       10.4

# %%
X = sm.add_constant(X, prepend=True)
modelo_api = sm.OLS(endog = y, exog = X,)
modelo_api = modelo_api.fit()
print(modelo_api.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ventas   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     360.8
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           1.61e-79
# Time:                        15:54:29   Log-Likelihood:                -986.30
# No. Observations:                 200   AIC:                             1981.
# Df Residuals:                     196   BIC:                             1994.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -33.2885      7.172     -4.641      0.000     -47.433     -19.144
# radio         -3.4496      0.206    -16.736      0.000      -3.856      -3.043
# tv             0.0450      0.118      0.382      0.703      -0.188       0.278
# periodico     18.4850      0.563     32.809      0.000      17.374      19.596
# ==============================================================================
# Omnibus:                       29.211   Durbin-Watson:                   2.143
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.239
# Skew:                           0.884   Prob(JB):                     1.83e-09
# Kurtosis:                       4.305   Cond. No.                         139.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **<font color="#07a8ed">Con scikit-learn:**
#
# [Documentación](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)

# %%
X = datos[["radio","tv","periodico"]]

# %%
modelo_sk = LinearRegression()
modelo_sk.fit(X, y)
print(modelo_sk.intercept_)
print(modelo_sk.coef_)
# Out:
# [-33.28853795]
# [[-3.44959312  0.04503377 18.48503551]]

# %% [markdown]
# ### **<font color="#07a8ed">Interpretación**

# %%
datos.columns
# Out:
# Index(['ventas', 'radio', 'tv', 'periodico'], dtype='object')

# %%
modelo_f.params.round(2)
# Out:
# Intercept   -33.29
# radio        -3.45
# tv            0.05
# periodico    18.49
# dtype: float64

# %% [markdown]
# $$ventas = -\ 33.29 - 3.45\ radio + 0.05\ tv + 18.49\ periodico$$

# %%
print(f"{datos.columns[0]} = {round(modelo_f.params[0],2)} {round(modelo_f.params[1],2)}{datos.columns[1]} + {round(modelo_f.params[2],2)}{datos.columns[2]} + {round(modelo_f.params[3],2)}{datos.columns[3]}")
# Out:
# ventas = -33.29 -3.45radio + 0.05tv + 18.49periodico
# <ipython-input-22-e5c1a51c7ffe>:1: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %% [markdown]
# ### **<font color="#07a8ed">Predicción y evaluación del modelo**

# %%
X.head(2)
# Out:
#    radio    tv  periodico
# 0   37.8  69.2       22.1
# 1   39.3  45.1       10.4

# %%
prediccion_1 = modelo_f.predict(X)

# %%
tabla = pd.DataFrame({"Prediccion":round(prediccion_1,1),
                      "Real": y.ventas,
                      "Ventas_medias": np.mean(y.ventas)})
tabla.head()
# Out:
#    Prediccion   Real  Ventas_medias
# 0       248.0  230.1       147.0425
# 1        25.4   44.5       147.0425
# 2       -16.6   17.2       147.0425
# 3       168.9  151.5       147.0425
# 4       170.5  180.8       147.0425

# %% [markdown]
# **<font color="#07a8ed">Standardised mean squared error (SMSE):**
#
# $$SMSE = \sqrt{MSE}=\sqrt{\frac{1}{n}\sum_{i=1}^{n}(y_i-\hat{y})^2}$$

# %%
SMSE = np.sqrt(sum((tabla.Real-tabla.Prediccion)**2)/(len(tabla))).round(2)
SMSE
# Out:
# 33.54

# %% [markdown]
# **<font color="#07a8ed">Mean Absolute Error(MAE):**
#
# $$MAE=\frac{1}{n}\sum_{i=1}^{n}|y_i-\hat{y}|$$

# %%
MAE = round(sum(abs(tabla.Real-tabla.Prediccion))/(len(tabla)),2)
MAE
# Out:
# 25.66

# %% [markdown]
# $R_2:$
#
# $$R_2 = 1-\frac{\frac{1}{n}\sum_{i=1}^{n}(y_i-\hat{y})^2}{\frac{1}{n}\sum_{i=1}^{n}(y_i-\bar{y})^2}$$
#
# Donde:
# * $\hat{y}$ es la predicción de la variable respuesta,
# * $\bar{y}$ es el promedio de la variable respuesta.

# %%
R2= round(1-((sum((tabla.Real-tabla.Prediccion)**2)/(len(tabla)))/(sum((tabla.Real-tabla.Ventas_medias)**2)/(len(tabla)))),2)
R2
# Out:
# 0.85

# %%
datos.periodico.iloc[0]
# Out:
# 22.1

# %%
#Ejemplo 1 variable (R2-gráfico)
fig = px.scatter(datos,
                 x="periodico",
                 y="ventas",
                 trendline="ols",
                 trendline_color_override="darkorange",
                 template="gridon"
)

fig.add_shape(type="line",
              x0=datos.periodico.min(), y0=np.mean(y.ventas), x1=datos.periodico.max(), y1=np.mean(y.ventas),
              line=dict(color="Red",width=2)
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5411a04a-b82f-474c-a088-7a4b17ceac2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1.6,3.2,4.8,5.3,5.3,5.5,5.6,5.7,5.9,6.6,6.6,6.7,6.9,7.0,7.2,7.2,7.3,7.3,7.6,7.6,8.0,8.1,8.4,8.5,8.6,8.7,8.7,8.7,8.8,8.8,9.2,9.3,9.3,9.4,9.5,9.5,9.5,9.6,9.6,9.7,9.7,9.7,9.7,9.7,9.9,10.1,10.1,10.1,10.3,10.3,10.4,10.4,10.5,10.5,10.6,10.6,10.6,10.7,10.8,10.8,10.9,10.9,11.0,11.0,11.2,11.3,11.3,11.4,11.4,11.5,11.5,11.6,11.6,11.6,11.7,11.7,11.7,11.7,11.8,11.8,11.8,11.9,11.9,11.9,12.0,12.0,12.2,12.2,12.2,12.3,12.4,12.5,12.5,12.6,12.6,12.7,12.8,12.8,12.9,12.9,12.9,12.9,13.2,13.2,13.2,13.3,13.4,13.4,13.4,13.6,14.0,14.1,14.2,14.4,14.5,14.6,14.6,14.7,14.7,14.8,14.8,14.9,14.9,15.0,15.0,15.2,15.2,15.3,15.5,15.5,15.5 ...

# %% [markdown]
# Podemos calcular las métricas anteriores (calculadas manualmente) usando el módulo `metrics` de `sklearn`:

# %%
SMSE = round(metrics.mean_squared_error(y, prediccion_1,squared=False),2) #Error cuadrático medio
MAE = round(metrics.mean_absolute_error(y, prediccion_1),2) #Error absoluto medio
R2 = round(metrics.r2_score(y, prediccion_1),4)
print("SMSE: {}".format(SMSE))
print("MAE: {}".format(MAE))
print("R2: {}".format(R2))
# Out:
# SMSE: 33.53
# MAE: 25.66
# R2: 0.8467
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %%
predicciones = modelo_f.get_prediction(X).summary_frame(alpha=0.1).round(2)
predicciones.head()
# Out:
#      mean  mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  obs_ci_upper
# 0  247.95     5.69         238.54         257.36        191.18        304.72
# 1   25.42     5.31          16.65          34.19        -31.25         82.08
# 2  -16.59     7.60         -29.16          -4.03        -73.97         40.78
# 3  168.85     4.38         161.61         176.09        112.40        225.30
# 4  170.54     5.16         162.02         179.07        113.91        227.17

# %% [markdown]
# ### **<font color="#07a8ed">Multicolinealidad**

# %%
corr_matrix = round(X.corr(),3)

# %%
px.imshow(corr_matrix,
          title = "Matriz de correlacion",
          text_auto = True,
          template = "gridon",
          labels={"color":"Coeficiente"})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de044a4e-b09e-4c5c-9d4a-56b1c15a691d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de044a4e-b09e-4c5c-9d4a-56b1c15a691d")) {                    Plotly.newPlot(                        "de044a4e-b09e-4c5c-9d4a-56b1c15a691d",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","x":["radio","tv","periodico"],"y":["radio","tv","periodico"],"z":[[1.0,0.354,0.576],[0.354,1.0,0.228],[0.576,0.228,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eCoeficiente: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"scaleanchor":"y","constrain":"domain"},"yaxis":{"anchor":"x","domain":[0.0,1.0],"autorange":"reversed","constrain":"domain"},"coloraxis":{"colorbar":{"title":{"text":"Coeficiente"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"title":{"text":"Matriz de correlacion"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('de044a4e-b09e-4c5c-9d4a-56b1c15a691d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# Las variables predictoras radio y periodico está correlacionadas. Es recomendable seleccionar una de ellas.

# %% [markdown]
# ## **<font color="#07a8ed">MODELO 2: periódico y radio y todos los datos**

# %%
modelo_2 = smf.ols(formula="ventas~radio+periodico", data=datos).fit()
print(modelo_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ventas   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     543.4
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           6.56e-81
# Time:                        16:04:09   Log-Likelihood:                -986.38
# No. Observations:                 200   AIC:                             1979.
# Df Residuals:                     197   BIC:                             1989.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -32.5203      6.869     -4.734      0.000     -46.067     -18.974
# radio         -3.4276      0.197    -17.358      0.000      -3.817      -3.038
# periodico     18.4919      0.562     32.909      0.000      17.384      19.600
# ==============================================================================
# Omnibus:                       28.595   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.741
# Skew:                           0.878   Prob(JB):                     3.87e-09
# Kurtosis:                       4.250   Cond. No.                         88.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <p align="justify">
# Los p-valores son extremadamente pequeño, garantizando que las variables son estadísticamente significativas y por lo tanto los parámetros no son 0.

# %% [markdown]
# ### **<font color="#07a8ed">Interpretación**

# %% [markdown]
# $$ventas = -32.52 - 3.43\ radio + 18.49\ periodico$$

# %% [markdown]
# ### **<font color="#07a8ed">Predicción y evaluación del modelo**

# %%
X.head(2)
# Out:
#    radio    tv  periodico
# 0   37.8  69.2       22.1
# 1   39.3  45.1       10.4

# %%
prediccion_2 = modelo_2.predict(X)

# %%
tabla = pd.DataFrame({"Prediccion":round(prediccion_2,1),
                      "Real":y.ventas})
tabla.head(8)
# Out:
#    Prediccion   Real
# 0       246.6  230.1
# 1        25.1   44.5
# 2       -17.9   17.2
# 3       168.0  151.5
# 4       169.0  180.8
# 5       -67.0    8.7
# 6        73.3   57.5
# 7       144.4  120.2

# %%
SMSE = round(metrics.mean_squared_error(y, prediccion_2, squared=False),2) #Error cuadrático medio
MAE = round(metrics.mean_absolute_error(y, prediccion_2),2) #Error absoluto medio
R2 = round(metrics.r2_score(y, prediccion_2),4)
print("SMSE: {}".format(SMSE))
print("MAE: {}".format(MAE))
print("R2: {}".format(R2))
# Out:
# SMSE: 33.55
# MAE: 25.63
# R2: 0.8466
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %% [markdown]
# ## **<font color="#07a8ed">MODELO 3: periódico y tv y todos los datos**

# %%
datos.head(3)
# Out:
#    ventas  radio    tv  periodico
# 0   230.1   37.8  69.2       22.1
# 1    44.5   39.3  45.1       10.4
# 2    17.2   45.9  69.3        9.3

# %%
modelo_3 = smf.ols(formula="ventas~tv+periodico", data=datos).fit()
print(modelo_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ventas   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.624
# Method:                 Least Squares   F-statistic:                     166.0
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           5.61e-43
# Time:                        16:04:41   Log-Likelihood:                -1075.0
# No. Observations:                 200   AIC:                             2156.
# Df Residuals:                     197   BIC:                             2166.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -24.7325     11.121     -2.224      0.027     -46.665      -2.800
# tv            -0.5071      0.176     -2.880      0.004      -0.854      -0.160
# periodico     13.3549      0.735     18.173      0.000      11.906      14.804
# ==============================================================================
# Omnibus:                       23.791   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.685
# Skew:                           0.913   Prob(JB):                     5.90e-07
# Kurtosis:                       3.331   Cond. No.                         118.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Este modelo disminuye considerablemente el $𝑅^2$, no se tendrá en cuenta.

# %%
prediccion_3 = modelo_3.predict(X)
SMSE = round(metrics.mean_squared_error(y, prediccion_3, squared=False),2) #Error cuadrático medio
MAE = round(metrics.mean_absolute_error(y, prediccion_3),2) #Error absoluto medio
R2 = round(metrics.r2_score(y, prediccion_3),4)
print("SMSE: {}".format(SMSE))
print("MAE: {}".format(MAE))
print("R2: {}".format(R2))
# Out:
# SMSE: 52.26
# MAE: 41.11
# R2: 0.6276
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %% [markdown]
# ## **<font color="#07a8ed">MODELO 4: periódico y radio y resultado positivo por región**

# %%
datos.head()
# Out:
#    ventas  radio    tv  periodico
# 0   230.1   37.8  69.2       22.1
# 1    44.5   39.3  45.1       10.4
# 2    17.2   45.9  69.3        9.3
# 3   151.5   41.3  58.5       18.5
# 4   180.8   10.8  58.4       12.9

# %% [markdown]
# El dataframe contiene por cada región, las ventas y la inversión en los canales de publicidad.

# %%
datos.sum()
# Out:
# ventas       29408.5
# radio         4652.8
# tv            6110.8
# periodico     2804.5
# dtype: float64

# %% [markdown]
# Se puede observar que las ventas totales superan ampliamente los gastos en canales de publicidad.

# %%
datos["utilidad"] = datos.ventas - datos.radio - datos.tv - datos.periodico

# %%
datos.head()
# Out:
#    ventas  radio    tv  periodico  utilidad
# 0   230.1   37.8  69.2       22.1     101.0
# 1    44.5   39.3  45.1       10.4     -50.3
# 2    17.2   45.9  69.3        9.3    -107.3
# 3   151.5   41.3  58.5       18.5      33.2
# 4   180.8   10.8  58.4       12.9      98.7

# %%
utilidad = round(datos.utilidad.sum(),2)
print(f"La utilidad total es: {utilidad}")
# Out:
# La utilidad total es: 15840.4

# %% [markdown]
# ### **<font color="#07a8ed">Filtrando por utilidad positiva**

# %%
utilidad = datos.query("utilidad > 0")
utilidad = utilidad.reset_index(drop = True)
utilidad.drop(columns = "utilidad", inplace = True)
utilidad
# Out:
#      ventas  radio    tv  periodico
# 0     230.1   37.8  69.2       22.1
# 1     151.5   41.3  58.5       18.5
# 2     180.8   10.8  58.4       12.9
# 3     120.2   19.6  11.6       13.2
# 4       8.6    2.1   1.0        4.8
# ..      ...    ...   ...        ...
# 148    38.2    3.7  13.8        7.6
# 149    94.2    4.9   8.1        9.7
# 150   177.0    9.3   6.4       12.8
# 151   283.6   42.0  66.2       25.5
# 152   232.1    8.6   8.7       13.4
#
# [153 rows x 4 columns]

# %%
X_utilidad = utilidad[['radio', 'tv', 'periodico']]
y_utilidad = utilidad["ventas"]

# %%
for i in X_utilidad.columns:
  fig = px.scatter(utilidad,
             x = i,
             y = y_utilidad,
             template = "gridon",
             title = i)
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c780c653-892a-436b-bbb0-4a44f5ab38e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c780c653-892a-436b-bbb0-4a44f5ab38e5")) {                    Plotly.newPlot(                        "c780c653-892a-436b-bbb0-4a44f5ab38e5",                        [{"hovertemplate":"radio=%{x}\u003cbr\u003eventas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[37.8,41.3,10.8,19.6,2.1,2.6,5.8,24.0,7.6,32.9,47.7,39.6,20.5,23.9,27.7,5.1,16.9,12.6,3.5,29.3,16.7,27.1,16.0,28.3,17.4,1.5,20.0,1.4,4.1,43.8,37.7,22.3,33.4,27.7,8.4,22.5,9.9,41.5,15.8,11.7,3.1,9.6,41.7,46.2,28.8,49.4,19.2,49.6,29.5,2.0,42.7,15.5,29.6,42.8,9.3,14.5,27.5,43.9,30.6,14.3,5.7,24.6,28.5,7.7,26.7,4.1,20.3,43.0,18.4,27.5,4.9,33.5,36.5,14.0,31.6,3.5,21.0,42.3,41.7,4.3,36.3,10.1,17.2,34.3,46.4,0.3,26.9,8.2,38.0,15.4,20.6,14.3,0.8,26.8,2.4,34.6,32.3,11.8,0.0,49.0,2.9,33
184.9,73.4,193.7,220.5,104.6,96.2,140.3,240.1,243.2,280.7,121.0,197.6,171.3,187.8,149.8,131.7,172.5,188.4,163.5,117.2,234.5,206.8,215.4,284.3,50.0,164.5,168.4,222.4,276.9,248.4,170.2,276.7,165.6,156.6,218.5,56.2,287.6,253.8,205.0,139.5,191.1,286.0,75.5,166.8,149.7,38.2,94.2,177.0,283.6,232.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"tv"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"ventas"}},"legend":{"tracegroupgap":0},"title":{"text":"tv"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('22242f9c-7788-4d3c-98b6-24e9620b1315');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="beeb588f-7ee8-454f-8df8-4a31caa5d765" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beeb588f-7ee8-454f-8df8-4a31caa5d765")) {                    Plotly.newPlot(                        "beeb588f-7ee8-454f-8df8-4a31caa5d765",                        [{"hovertemplate":"periodico=%{x}\u003cbr\u003eventas=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#1F77B4","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[22.1,18.5,12.9,13.2,4.8,10.6,8.6,17.4,9.7,19.0,22.4,24.4,11.3,14.6,18.0,12.5,15.5,9.7,12.0,15.0,15.9,18.9,10.5,21.4,11.9,9.6,17.4,9.5,12.8,25.4,21.5,16.6,17.1,20.7,12.9,14.9,10.6,23.2,14.8,9.7,11.4,10.7,22.6,21.2,20.2,23.7,13.2,23.8,18.4,8.1,24.2,15.7,14.0,18.0,9.3,13.4,18.9,22.3,18.3,12.4,11.0,17.0,14.2,11.0,11.8,12.3,11.3,21.7,15.2,12.0,11.2,19.4,22.2,11.5,16.9,11.7,15.5,25.4,17.2,11.7,23.8,14.8,14.7,20.7,19.2,8.7,19.8,13.4,21.8,14.1,15.9,12.2,9.4,15.5,11.6,15.2,19.7,10.6,8.8,24.7,12.7,19.6,20.8,20.7,10.9,19.2,20.1,10.4,11.4,10.3,13.2,25.4,16.1,11.6,16.6,19.0,15.6,10.1,12.9,14.4,14.9,18.0,11.9,11.9,12.2,17.1,15.0,8.4,14.5,11.7,11.5,27.0,20.2,11.7,11.8,12.6,10.5,12.2,8.7,26.2,17.6,22.6,10.3,17.3,15.9,9.9,19.6,17.3,7.6,9.7,12.8,25.5,13.4],"xaxis":"x","y":[230.1,151.5,180.8,120.2,8.6,199.8,66.1,214.7,97.5,204.1,195.4,281.4,69.2,147.3,218.4,237.4,228.3,62.3,262.9,142.9,240.1,248.8,70.6,292.9,112.9,97.2,265.6,95.7,290.7,266.9,228.0,202.5,177.0,293.6,206.9,175.1,89.7,239.9,227.2,66.9,199.8,100.4,216.4,182.6,262.7,198.9,136.2,210.8,210.7,53.5,261.3,239.3,102.7,131.1,69.0,139.3,237.4,216.8,199.1,109.8,129.4,213.4,120.5,116.0,76.4,239.8,75.3,213.5,193.2,76.3,134.3,217.7,250.9,107.4,163.3,197.6,184.9,289.7,135.2,222.4,296.4,280.2,187.9,238.2,137.9,90.4,255.4,225.8,241.7,175.7,209.6,139.2,76.4,141.3,224.0,123.1,229.5,87.2,80.2,220.3,265.2,219.8,273.7,184.9,73.4,193.7,220.5,104.6,96.2,140.3,240.1,243.2,280.7,121.0,197.6,171.3,187.8,149.8,131.7,172.5,188.4,163.5,117.2,234.5,206.8,215.4,284.3,50.0,164.5,168.4,222.4,276.9,248.4,170.2,276.7,165.6,156.6,218.5,56.2,287.6,253.8,205.0,139.5,191.1,286.0,75.5,166.8,149.7,38.2,94.2,177.0,283.6,232.1],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}]},"layout":{"xaxis":{"showgrid":true,"title":{"standoff":15}},"yaxis":{"showgrid":true,"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"periodico"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"ventas"}},"legend":{"tracegroupgap":0},"title":{"text":"periodico"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('beeb588f-7ee8-454f-8df8-4a31caa5d765');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### **<font color="#07a8ed">Creación del modelo**

# %%
utilidad
# Out:
#      ventas  radio    tv  periodico
# 0     230.1   37.8  69.2       22.1
# 1     151.5   41.3  58.5       18.5
# 2     180.8   10.8  58.4       12.9
# 3     120.2   19.6  11.6       13.2
# 4       8.6    2.1   1.0        4.8
# ..      ...    ...   ...        ...
# 148    38.2    3.7  13.8        7.6
# 149    94.2    4.9   8.1        9.7
# 150   177.0    9.3   6.4       12.8
# 151   283.6   42.0  66.2       25.5
# 152   232.1    8.6   8.7       13.4
#
# [153 rows x 4 columns]

# %%
modelo_4 = smf.ols(formula="ventas~radio+periodico", data=utilidad).fit()
print(modelo_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ventas   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.861
# Method:                 Least Squares   F-statistic:                     473.0
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           1.67e-65
# Time:                        16:07:13   Log-Likelihood:                -711.31
# No. Observations:                 153   AIC:                             1429.
# Df Residuals:                     150   BIC:                             1438.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -107.7656      9.595    -11.232      0.000    -126.724     -88.808
# radio         -6.6866      0.325    -20.605      0.000      -7.328      -6.045
# periodico     27.8006      0.974     28.534      0.000      25.876      29.726
# ==============================================================================
# Omnibus:                        0.430   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.806   Jarque-Bera (JB):                0.152
# Skew:                           0.003   Prob(JB):                        0.927
# Kurtosis:                       3.154   Cond. No.                         140.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### **<font color="#07a8ed">Interpretación**

# %% [markdown]
# $$ventas = -\ 107.77 - 6.68\ radio + 27.80\ periodico$$

# %% [markdown]
# ### **<font color="#07a8ed">Predicción y evaluación del modelo**

# %%
X_utilidad.head(2)
# Out:
#    radio    tv  periodico
# 0   37.8  69.2       22.1
# 1   41.3  58.5       18.5

# %%
prediccion_4 = modelo_4.predict(X_utilidad)
prediccion_4
# Out:
# 0      253.876450
# 1      130.391224
# 2      178.647704
# 3      128.146184
# 4       11.635642
#           ...
# 148     78.778918
# 149    129.136374
# 150    185.897477
# 151    320.315054
# 152    207.258447
# Length: 153, dtype: float64

# %%
SMSE = round(metrics.mean_squared_error(y_utilidad, prediccion_4, squared=False),2) #Error cuadrático medio
MAE = round(metrics.mean_absolute_error(y_utilidad, prediccion_4),2) #Error absoluto medio
R2 = round(metrics.r2_score(y_utilidad, prediccion_4),4)
print("SMSE: {}".format(SMSE))
print("MAE: {}".format(MAE))
print("R2: {}".format(R2))
# Out:
# SMSE: 25.28
# MAE: 19.64
# R2: 0.8631
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %%
px.scatter_3d(utilidad,
              x="radio",
              y="periodico",
              z="ventas")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f6f5ecf-fd7e-4dcb-9ef8-293e1f7377d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f6f5ecf-fd7e-4dcb-9ef8-293e1f7377d2")) {                    Plotly.newPlot(                        "5f6f5ecf-fd7e-4dcb-9ef8-293e1f7377d2",                        [{"hovertemplate":"radio=%{x}\u003cbr\u003eperiodico=%{y}\u003cbr\u003eventas=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[37.8,41.3,10.8,19.6,2.1,2.6,5.8,24.0,7.6,32.9,47.7,39.6,20.5,23.9,27.7,5.1,16.9,12.6,3.5,29.3,16.7,27.1,16.0,28.3,17.4,1.5,20.0,1.4,4.1,43.8,37.7,22.3,33.4,27.7,8.4,22.5,9.9,41.5,15.8,11.7,3.1,9.6,41.7,46.2,28.8,49.4,19.2,49.6,29.5,2.0,42.7,15.5,29.6,42.8,9.3,14.5,27.5,43.9,30.6,14.3,5.7,24.6,28.5,7.7,26.7,4.1,20.3,43.0,18.4,27.5,4.9,33.5,36.5,14.0,31.6,3.5,21.0,42.3,41.7,4.3,36.3,10.1,17.2,34.3,46.4,0.3,26.9,8.2,38.0,15.4,20.6,14.3,0.8,26.8,2.4,34.6,32.3,11.8,0.0,49.0,2.9,33.5,28.9,43.9,17.0,35.4,33.2,5.7,14.8,1.9,7.3