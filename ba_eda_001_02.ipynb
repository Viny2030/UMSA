# %% [markdown]
# <p align="center">
# <img src="https://www.python.org/static/community_logos/python-powered-h-70x91.png?raw=true" width="100" height="">
# </p>

# %% [markdown]
#  # **<font color="#07a8ed">Análisis Exploratorio y Preprocesamiento de los Datos</font>**

# %% [markdown]
# ## **<font color="#07a8ed">Bibliotecas**

# %% [markdown]
# ### **<font color="#07a8ed">Para análisis de datos**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **<font color="#07a8ed">Para preprocesamiento de datos**

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html

# %% [markdown]
#  ## **<font color="#07a8ed">Obtención de los Datos</font>**

# %%
url = "https://raw.githubusercontent.com/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/main/Modulo_08_Aprendizaje_Automatico/visualizacion.csv"

# %%
analisis = pd.read_csv(url)  ## conecto la url del dataset
analisis.head()  ## descargo dataset con el encabezado
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# Se cambian los nombres de las columnas para mejor interpretacion.

# %%
analisis.info() ## info del dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
analisis.rename(columns={"satisfaction_level":"niveldesatisfaccion", ### renombro las columnas en español
                         "last_evaluation":"ultimaevaluacion",
                         "number_project":"numerosdeproyectos",
                         "average_montly_hours":"horasmensualespromedio",
                         "time_spend_company":"tiempoenlaempresa",
                         "Work_accident":"accidentedetrabajo",
                         "left":"abandono",
                         "promotion_last_5years":"promocionultimos5años",
                         "sales":"ventas",
                         "salary":"sueldo"}, inplace= True)

# %%
analisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   niveldesatisfaccion     14999 non-null  float64
#  1   ultimaevaluacion        14999 non-null  float64
#  2   numerosdeproyectos      14999 non-null  int64
#  3   horasmensualespromedio  14999 non-null  int64
#  4   tiempoenlaempresa       14999 non-null  int64
#  5   accidentedetrabajo      14999 non-null  int64
#  6   abandono                14999 non-null  int64
#  7   promocionultimos5años   14999 non-null  int64
#  8   ventas                  14999 non-null  object
#  9   sueldo                  14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
###analisis.sueldo.value_counts()

# %% [markdown]
#  ## **<font color="#07a8ed">Limpieza y transformación de datos</font>**

# %% [markdown]
#  ### **<font color="#07a8ed">Filtrado de datos</font>**

# %%
analisis.head(2)
# Out:
#    niveldesatisfaccion  ultimaevaluacion  numerosdeproyectos  \
# 0                 0.38              0.53                   2
# 1                 0.80              0.86                   5
#
#    horasmensualespromedio  tiempoenlaempresa  accidentedetrabajo  abandono  \
# 0                     157                  3                   0         1
# 1                     262                  6                   0         1
#
#    promocionultimos5años ventas  sueldo
# 0                      0  sales     low
# 1                      0  sales  medium

# %%
analisis.ventas.value_counts()
# Out:
# ventas
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
analisis.rename(columns={"ventas":"sector"}, inplace=True)  ## renombro columna ventas por sector

# %%
analisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   niveldesatisfaccion     14999 non-null  float64
#  1   ultimaevaluacion        14999 non-null  float64
#  2   numerosdeproyectos      14999 non-null  int64
#  3   horasmensualespromedio  14999 non-null  int64
#  4   tiempoenlaempresa       14999 non-null  int64
#  5   accidentedetrabajo      14999 non-null  int64
#  6   abandono                14999 non-null  int64
#  7   promocionultimos5años   14999 non-null  int64
#  8   sector                  14999 non-null  object
#  9   sueldo                  14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
analisis.filter(["sector", "sueldo"])  ## filtrar por sector y sueldo
# Out:
#         sector  sueldo
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# 3        sales     low
# 4        sales     low
# ...        ...     ...
# 14994  support     low
# 14995  support     low
# 14996  support     low
# 14997  support     low
# 14998  support     low
#
# [14999 rows x 2 columns]

# %%
analisis.sueldo.value_counts()
# Out:
# sueldo
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
###analisis.sueldo.value_counts()/len(analisis.sueldo)  ### variable objetivo ?

# %%
analisis.filter([0,1,2,5,7,19],axis=0)  ## filtro algunas filas por numero  axis = 0
# Out:
#     niveldesatisfaccion  ultimaevaluacion  numerosdeproyectos  \
# 0                  0.38              0.53                   2
# 1                  0.80              0.86                   5
# 2                  0.11              0.88                   7
# 5                  0.41              0.50                   2
# 7                  0.92              0.85                   5
# 19                 0.76              0.89                   5
#
#     horasmensualespromedio  tiempoenlaempresa  accidentedetrabajo  abandono  \
# 0                      157                  3                   0         1
# 1                      262                  6                   0         1
# 2                      272                  4                   0         1
# 5                      153                  3                   0         1
# 7                      259                  5                   0         1
# 19                     262                  5                   0         1
#
#     promocionultimos5años sector  sueldo
# 0                       0  sales     low
# 1                       0  sales  medium
# 2                       0  sales  medium
# 5                       0  sales     low
# 7                       0  sales     low
# 19                      0  sales     low

# %%
analisis[analisis.sector=="support"] ## filtrar por el dato de support en la columna de sector
# Out:
#        niveldesatisfaccion  ultimaevaluacion  numerosdeproyectos  \
# 46                    0.40              0.55                   2
# 47                    0.57              0.70                   3
# 48                    0.40              0.54                   2
# 49                    0.43              0.47                   2
# 50                    0.13              0.78                   6
# ...                    ...               ...                 ...
# 14994                 0.40              0.57                   2
# 14995                 0.37              0.48                   2
# 14996                 0.37              0.53                   2
# 14997                 0.11              0.96                   6
# 14998                 0.37              0.52                   2
#
#        horasmensualespromedio  tiempoenlaempresa  accidentedetrabajo  \
# 46                        147                  3                   0
# 47                        273                  6                   0
# 48                        148                  3                   0
# 49                        147                  3                   0
# 50                        152                  2                   0
# ...                       ...                ...                 ...
# 14994                     151                  3                   0
# 14995                     160                  3                   0
# 14996                     143                  3                   0
# 14997                     280                  4                   0
# 14998                     158                  3                   0
#
#        abandono  promocionultimos5años   sector sueldo
# 46            1                      0  support    low
# 47            1                      0  support    low
# 48            1                      0  support    low
# 49            1                      0  support    low
# 50            1                      0  support    low
# ...         ...                    ...      ...    ...
# 14994         1                      0  support    low
# 14995         1                      0  support    low
# 14996         1                      0  support    low
# 14997         1                      0  support    low
# 14998         1                      0  support    low
#
# [2229 rows x 10 columns]

# %% [markdown]
#  ### **<font color="#07a8ed">Valores faltantes</font>**

# %%
url2 = "https://raw.githubusercontent.com/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/main/Modulo_08_Aprendizaje_Automatico/empleados.csv"

# %%
empleados = pd.read_csv(url2)

# %%
empleados  ## dataset empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
###empleados.info()

# %% [markdown]
#  ### **<font color="#07a8ed">Eliminando los NaN</font>**

# %%
empleados.dropna(how="any", inplace=True)

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
##empleados.info()

# %% [markdown]
#  ### **<font color="#07a8ed">Completando los NaN</font>**

# %%
empleados = pd.read_csv(url2)
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleados["edad"] = empleados.edad.fillna(empleados.edad.mean())
empleados
# Out:
#              nombre       edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.000000      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar  40.428571  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.000000  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.000000  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.000000  42000.0    F  Operations    G2          711
# 5     Samara Sharma  40.428571  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.000000      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.000000  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.000000  98000.0    M       Sales    G4          709

# %%
empleados = pd.read_csv(url2)
empleados["edad"] = round(empleados.edad.fillna(empleados.edad.mean()),0)  ## imputo la columna edad con la media
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar  40.0  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma  40.0  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleados = pd.read_csv(url2)
empleados["edad"] = empleados.edad.fillna(empleados.edad.median())
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar  45.0  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma  45.0  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleados["sueldo"] = empleados.sueldo.fillna(empleados.sueldo.median())  ##imputo la columna sueldo con la mediana
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0  52000.0  NaN  Operations    G3          723
# 1      Sandro Kumar  45.0  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma  45.0  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0  52000.0    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %% [markdown]
#  ## **<font color="#07a8ed">Codificación de variables categóricas</font>**

# %% [markdown]
#  ### **<font color="#07a8ed">Método <code>get_dummies</code></font>**

# %% [markdown]
# <p align="justify">
# El método <code>get_dummies</code> de Pandas se utiliza principalmente para convertir variables categóricas en variables ficticias o numéricas, lo que permite su uso en algoritmos de aprendizaje automático que requieren datos numéricos como entrada.

# %%
empleados = pd.read_csv(url2)
empleados.dropna(how="any", inplace=True)
empleados.reset_index(drop=True, inplace=True)
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 1      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 2    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 3      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 4  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleadoscodificados = pd.get_dummies(empleados["sexo"])  ## genero un objeto con las columnas codificadas por get dummies

# %%
empleadoscodificados
# Out:
#        F      M
# 0  False   True
# 1   True  False
# 2   True  False
# 3   True  False
# 4  False   True

# %%
empleados = empleados.join(empleadoscodificados) ### al objeto empleados le adjunto el de empleados codificados
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-2e524e909747> in <cell line: 1>()
# ----> 1 empleados = empleados.join(empleadoscodificados) ### al objeto empleados le adjunto el de empleados codificados
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10410                     validate=validate,
#   10411                 )
# > 10412             return merge(
#   10413                 self,
#   10414                 other,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     181             validate=validate,
#     182         )
# --> 183         return op.get_result(copy=copy)
#     184
#     185
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     883         join_index, left_indexer, right_indexer = self._get_join_info()
#     884
# --> 885         result = self._reindex_and_concat(
#     886             join_index, left_indexer, right_indexer, copy=copy
#     887         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     835         right = self.right[:]
#     836
# --> 837         llabels, rlabels = _items_overlap_with_suffix(
#     838             self.left._info_axis, self.right._info_axis, self.suffixes
#     839         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2659
#    2660     if not lsuffix and not rsuffix:
# -> 2661         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2662
#    2663     def renamer(x, suffix: str | None):
#
# ValueError: columns overlap but no suffix specified: Index(['F', 'M'], dtype='object')

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance      F  \
# 0    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674  False
# 1      Ernesto Chin  45.0  65000.0    F       Sales    G3          556   True
# 2    Fernanda Patel  30.0  42000.0    F  Operations    G2          711   True
# 3      Juana Wilkis  54.0  52000.0    F     Finance    G3          901   True
# 4  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709  False
#
#        M
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
##empleados.info()

# %%
empleados = empleados.drop(columns = ["sexo"], axis=1)  ## al dataset de empleados dropeo la columna sexo

# %%
empleados
# Out:
#              nombre  edad   sueldo      sector nivel  performance      F  \
# 0    Jacinto Morgan  32.0  35000.0     Finance    G2          674  False
# 1      Ernesto Chin  45.0  65000.0       Sales    G3          556   True
# 2    Fernanda Patel  30.0  42000.0  Operations    G2          711   True
# 3      Juana Wilkis  54.0  52000.0     Finance    G3          901   True
# 4  Leonardo Doberti  23.0  98000.0       Sales    G4          709  False
#
#        M
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
empleados = pd.read_csv(url2)
empleados.dropna(how="any", inplace=True)
empleados.reset_index(drop=True, inplace=True)
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 1      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 2    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 3      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 4  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleados = empleados.join(pd.get_dummies(empleados["sexo"], prefix="sexo"))
empleados.drop(columns = "sexo", inplace = True)

# %%
empleados
# Out:
#              nombre  edad   sueldo      sector nivel  performance  sexo_F  \
# 0    Jacinto Morgan  32.0  35000.0     Finance    G2          674   False
# 1      Ernesto Chin  45.0  65000.0       Sales    G3          556    True
# 2    Fernanda Patel  30.0  42000.0  Operations    G2          711    True
# 3      Juana Wilkis  54.0  52000.0     Finance    G3          901    True
# 4  Leonardo Doberti  23.0  98000.0       Sales    G4          709   False
#
#    sexo_M
# 0    True
# 1   False
# 2   False
# 3   False
# 4    True

# %% [markdown]
# Otra forma más directa:

# %%
empleados = pd.read_csv(url2)
empleados.dropna(how="any", inplace=True)
empleados.reset_index(drop=True, inplace=True)
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 1      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 2    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 3      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 4  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
empleados = pd.get_dummies(data=empleados, columns=['sexo'])
empleados
# Out:
#              nombre  edad   sueldo      sector nivel  performance  sexo_F  \
# 0    Jacinto Morgan  32.0  35000.0     Finance    G2          674   False
# 1      Ernesto Chin  45.0  65000.0       Sales    G3          556    True
# 2    Fernanda Patel  30.0  42000.0  Operations    G2          711    True
# 3      Juana Wilkis  54.0  52000.0     Finance    G3          901    True
# 4  Leonardo Doberti  23.0  98000.0       Sales    G4          709   False
#
#    sexo_M
# 0    True
# 1   False
# 2   False
# 3   False
# 4    True

# %% [markdown]
# ### **<font color="#07a8ed">Método <code>LabelEncoder</code></font>**

# %% [markdown]
# <p align="justify">
# El método <code>LabelEncoder</code> de la biblioteca scikit-learn se utiliza para codificar variables categóricas en valores numéricos. Toma como entrada una lista de etiquetas y asigna un número entero único a cada etiqueta.

# %%
empleados = pd.read_csv(url2)
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709

# %%
etiqueta_ordenada = LabelEncoder()

# %%
empleados["nivel_cod"] = etiqueta_ordenada.fit_transform(empleados["nivel"])

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#    nivel_cod
# 0          2
# 1          0
# 2          1
# 3          2
# 4          1
# 5          2
# 6          2
# 7          2
# 8          3

# %% [markdown]
#  ## **<font color="#07a8ed">Escalado de variables numéricas</font>**

# %% [markdown]
# ### **<font color="#07a8ed">Método <code>StandardScaler</code></font>**

# %% [markdown]
# <p align="justify">
# El método <code>StandardScaler</code> de la biblioteca scikit-learn se utiliza para estandarizar variables numéricas. La estandarización de las variables significa que cada variable tendrá una media de cero y una desviación estándar de uno. Esto asegura que las variables estén en la misma escala, lo que puede mejorar el rendimiento de muchos algoritmos de aprendizaje automático.

# %%
escala = StandardScaler()

# %%
escala.fit(empleados[["performance"]])
# Out:
# StandardScaler()

# %%
empleados["escala_perform"]=escala.transform(empleados[["performance"]])

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#    nivel_cod  escala_perform
# 0          2        0.505565
# 1          0       -0.408053
# 2          1        0.285037
# 3          2       -0.246032
# 4          1        0.451558
# 5          2        0.172522
# 6          2       -2.509823
# 7          2        1.306668
# 8          3        0.442557

# %%
empleados.escala_perform.describe()
# Out:
# count    9.000000e+00
# mean     1.912051e-16
# std      1.060660e+00
# min     -2.509823e+00
# 25%     -2.460317e-01
# 50%      2.850367e-01
# 75%      4.515581e-01
# max      1.306668e+00
# Name: escala_perform, dtype: float64

# %% [markdown]
# ### **<font color="#07a8ed">Método <code>MinMaxScaler</code></font>**

# %% [markdown]
# <p align="justify">
# El método <code>MinMaxScaler</code> de la biblioteca scikit-learn se utiliza para escalar características al rango dado por un mínimo y un máximo específicos, generalmente entre 0 y 1. Esto es útil cuando deseas preservar la forma de la distribución original mientras ajustas los valores dentro de un rango específico.

# %%
escalaminmax = MinMaxScaler()

# %%
escalaminmax.fit(empleados[["performance"]])
# Out:
# MinMaxScaler()

# %%
empleados["escala_minmax"]=escalaminmax.transform(empleados[["performance"]])

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#    nivel_cod  escala_perform  escala_minmax
# 0          2        0.505565       0.790094
# 1          0       -0.408053       0.550708
# 2          1        0.285037       0.732311
# 3          2       -0.246032       0.593160
# 4          1        0.451558       0.775943
# 5          2        0.172522       0.702830
# 6          2       -2.509823       0.000000
# 7          2        1.306668       1.000000
# 8          3        0.442557       0.773585

# %% [markdown]
# ### **<font color="#07a8ed">Método <code>RobustScaler</code></font>**

# %% [markdown]
# <p align="justify">
# El método <code>RobustScaler</code> de la biblioteca scikit-learn se utiliza para escalar variables utilizando estadísticas resistentes a los valores atípicos. Esto significa que <code>RobustScaler</code> ajusta y transforma los datos utilizando la mediana y el rango intercuartílico, lo que hace que sea menos sensible a los valores atípicos en comparación con <code>StandarScaler</code> o <code>MinMaxScaler</code>

# %%
escala_robusta = RobustScaler()

# %%
escala_robusta.fit(empleados[["performance"]])
# Out:
# RobustScaler()

# %%
empleados["escala_robusta"]=escala_robusta.transform(empleados[["performance"]])

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#    nivel_cod  escala_perform  escala_minmax  escala_robusta
# 0          2        0.505565       0.790094        0.316129
# 1          0       -0.408053       0.550708       -0.993548
# 2          1        0.285037       0.732311        0.000000
# 3          2       -0.246032       0.593160       -0.761290
# 4          1        0.451558       0.775943        0.238710
# 5          2        0.172522       0.702830       -0.161290
# 6          2       -2.509823       0.000000       -4.006452
# 7          2        1.306668       1.000000        1.464516
# 8          3        0.442557       0.773585        0.225806

# %%
empleados1 = empleados.copy()

# %%
empleados1['escala'] = empleados1.escala_perform - empleados1.escala_minmax-empleados1.escala_robusta

# %%
empleados1
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#    nivel_cod  escala_perform  escala_minmax  escala_robusta    escala
# 0          2        0.505565       0.790094        0.316129 -0.600658
# 1          0       -0.408053       0.550708       -0.993548  0.034788
# 2          1        0.285037       0.732311        0.000000 -0.447275
# 3          2       -0.246032       0.593160       -0.761290 -0.077902
# 4          1        0.451558       0.775943        0.238710 -0.563095
# 5          2        0.172522       0.702830       -0.161290 -0.369018
# 6          2       -2.509823       0.000000       -4.006452  1.496628
# 7          2        1.306668       1.000000        1.464516 -1.157848
# 8          3        0.442557       0.773585        0.225806 -0.556834

# %% [markdown]
# ###Analisis de escalas

# %%
import plotly.express as px

# %%
px.line(empleados1, x="escala_robusta")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="abe8d1b8-b638-4d4d-8261-08971d8e2e45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abe8d1b8-b638-4d4d-8261-08971d8e2e45")) {                    Plotly.newPlot(                        "abe8d1b8-b638-4d4d-8261-08971d8e2e45",                        [{"hovertemplate":"escala_robusta=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[0.3161290322580645,-0.9935483870967742,0.0,-0.7612903225806451,0.23870967741935484,-0.16129032258064516,-4.006451612903226,1.4645161290322581,0.22580645161290322],"xaxis":"x","y":[0,1,2,3,4,5,6,7,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10," ...

# %%
px.line(empleados1, x="escala_minmax")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f58e5857-890c-4895-82ae-4cd7760b40f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f58e5857-890c-4895-82ae-4cd7760b40f9")) {                    Plotly.newPlot(                        "f58e5857-890c-4895-82ae-4cd7760b40f9",                        [{"hovertemplate":"escala_minmax=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[0.7900943396226415,0.5507075471698113,0.7323113207547169,0.5931603773584906,0.7759433962264151,0.7028301886792453,0.0,1.0,0.7735849056603773],"xaxis":"x","y":[0,1,2,3,4,5,6,7,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %%
px.line(empleados1, x="escala_perform")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bfd3a911-071a-443e-ae90-a9402f84c1e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfd3a911-071a-443e-ae90-a9402f84c1e0")) {                    Plotly.newPlot(                        "bfd3a911-071a-443e-ae90-a9402f84c1e0",                        [{"hovertemplate":"escala_perform=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[0.5055650956968765,-0.4080525401470335,0.28503670083800164,-0.24603167861806427,0.45155814185388676,0.17252221366510634,-2.509823160536718,1.3066682443678912,0.4425569828800551],"xaxis":"x","y":[0,1,2,3,4,5,6,7,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overl ...

# %%
px.line(empleados1, x="escala")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="17265e8c-fde9-4eef-bc8a-d81f92e081eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17265e8c-fde9-4eef-bc8a-d81f92e081eb")) {                    Plotly.newPlot(                        "17265e8c-fde9-4eef-bc8a-d81f92e081eb",                        [{"hovertemplate":"escala=%{x}\u003cbr\u003eindex=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"h","showlegend":false,"x":[-0.6006582761838295,0.034788299779929366,-0.4472746199167153,-0.07790173339590978,-0.5630949317918832,-0.3690176524334938,1.496628452366508,-1.157847884664367,-0.5568343743932254],"xaxis":"x","y":[0,1,2,3,4,5,6,7,8],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","s ...

# %% [markdown]
# ## **<font color="#07a8ed">Transformación de variables numéricas a categóricas</code></font>**

# %%
empleados = pd.read_csv(url2)

# %%
def grado_performance(performance):
    if performance >= 700:
        return "A"
    elif performance < 700 and performance >= 500:
        return "B"
    else:
        return "C"

# %%
empleados["grado_performance"] = empleados.performance.apply(grado_performance)

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel  performance  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3          723
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0          520
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2          674
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3          556
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2          711
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3          649
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           53
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3          901
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4          709
#
#   grado_performance
# 0                 A
# 1                 B
# 2                 B
# 3                 B
# 4                 A
# 5                 B
# 6                 C
# 7                 A
# 8                 A

# %%
empleados = pd.read_csv(url2)

# %%
empleados.performance = empleados.performance.apply(grado_performance)

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel performance
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3           A
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0           B
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2           B
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3           B
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2           A
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3           B
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           C
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3           A
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4           A

# %%
empleados_nivel = pd.get_dummies(empleados["nivel"])

# %%
empleados_nivel
# Out:
#       G0     G2     G3     G4
# 0  False  False   True  False
# 1   True  False  False  False
# 2  False   True  False  False
# 3  False  False   True  False
# 4  False   True  False  False
# 5  False  False   True  False
# 6  False  False   True  False
# 7  False  False   True  False
# 8  False  False  False   True

# %%
empleados = empleados.join(empleados_nivel)

# %%
empleados
# Out:
#              nombre  edad   sueldo sexo      sector nivel performance     G0  \
# 0        Alan Smith  45.0      NaN  NaN  Operations    G3           A  False
# 1      Sandro Kumar   NaN  16000.0    F     Finance    G0           B   True
# 2    Jacinto Morgan  32.0  35000.0    M     Finance    G2           B  False
# 3      Ernesto Chin  45.0  65000.0    F       Sales    G3           B  False
# 4    Fernanda Patel  30.0  42000.0    F  Operations    G2           A  False
# 5     Samara Sharma   NaN  62000.0  NaN       Sales    G3           B  False
# 6   Joaquin Fleiman  54.0      NaN    F  Operations    G3           C  False
# 7      Juana Wilkis  54.0  52000.0    F     Finance    G3           A  False
# 8  Leonardo Doberti  23.0  98000.0    M       Sales    G4           A  False
#
#       G2     G3     G4
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False   True  False
# 4   True  False  False
# 5  False   True  False
# 6  False   True  False
# 7  False   True  False
# 8  False  False   True
