# %% [markdown]
# <p align="center">
# <img src="https://pypi.org/static/images/logo-small.8998e9d1.svg" width="" height="">
# </p>

# %% [markdown]
# # **<font color="#07a8ed">Matriz de correlación con Python**

# %% [markdown]
# ## **<font color="#07a8ed">Bibliotecas**

# %% [markdown]
# ### **<font color="#07a8ed">Para análisis de datos**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **<font color="#07a8ed">Para análisis gráfico**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# https://seaborn.pydata.org

# %% [markdown]
#  ## **<font color="#07a8ed">Obtención de los Datos</font>**

# %%
url = "https://raw.githubusercontent.com/LucaAPiattelli/Diplomatura_Business_Analytics_UDA/main/Modulo_08_Aprendizaje_Automatico/visualizacion.csv"

# %%
analisis = pd.read_csv(url)
analisis.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# Se cambian los nombres de las columnas para mejor interpretacion

# %%
analisis.rename(columns={"satisfaction_level":"niveldesatisfaccion",
                         "last_evaluation":"ultimaevaluacion",
                         "number_project":"numerosdeproyectos",
                         "average_montly_hours":"horasmensualespromedio",
                         "time_spend_company":"tiempoenlaempresa",
                         "Work_accident":"accidentedetrabajo",
                         "left":"abandono",
                         "promotion_last_5years":"promocionultimos5años",
                         "sales":"ventas",
                         "salary":"sueldo"}, inplace= True)

# %%
analisis.columns
# Out:
# Index(['niveldesatisfaccion', 'ultimaevaluacion', 'numerosdeproyectos',
#        'horasmensualespromedio', 'tiempoenlaempresa', 'accidentedetrabajo',
#        'abandono', 'promocionultimos5años', 'ventas', 'sueldo'],
#       dtype='object')

# %% [markdown]
#  ## **<font color="#07a8ed">Matriz de correlación</font>**

# %% [markdown]
# <p align="justify">
# La correlación estadística constituye una técnica estadística que  indica si las variables están relacionadas o no lo están.
# <br><br>
# Por ejemplo, en las variables del ingreso familiar y el gasto familiar se sabe que un aumento en los ingresos genera un aumento en los gastos, y una disminución de los ingresos, genera una disminución de los gastos. Por lo tanto, las variables ingresos y gastos están relacionadas y un cambio en cualquiera de esas variables estará acompañado por un cambio en la otra variable en el mismo sentido, o con el mismo signo.
# <br><br>
# De la misma manera, los precios y la demanda de un producto son variables relacionadas; cuando los precios aumentan la demanda tenderá a disminuir y viceversa.
# <br><br>
# En el caso del ingreso familiar y el gasto familiar, es fácil ver que ambos suben o bajan juntos en la misma dirección. Esto se denomina <b>correlación positiva</b>.
# <br><br>
# En caso del precio y la demanda, el cambio se produce en la dirección opuesta, de modo que el aumento de una variables está acompañado de una disminución en la otra variable. Esto se conoce como <b>correlación negativa</b>.

# %% [markdown]
#  ## **<font color="#07a8ed">Matriz de correlación - Método Pearson</font>**

# %% [markdown]
# <p align="justify">
# La correlación de Pearson funciona bien con variables cuantitativas que tienen una distribución normal o próxima a la normal. Es más sensible a los valores extremos que las otras dos alternativas, Spearman y Kendall.
# <BR><BR>
# La correlación de Spearman se emplea con variables cuantitativas (continuas o discretas). En lugar de utilizar directamente el valor de cada variable, los datos son ordenados y reemplazados por su respectivo orden ranking. Es un método no paramétrico muy utilizado cuando no se satisface la condición de normalidad necesaria para aplicar la correlación de Pearson.
# <BR><BR>
# La correlación de Kendall es otra alternativa no paramétrica que, al igual que la correlación de Spearman, utiliza la ordenación de las observaciones ranking. Es recomendable cuando se dispone de pocos datos.

# %%
pearson = analisis.corr(method="pearson", numeric_only=True)

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.105021
# ultimaevaluacion                   0.105021          1.000000
# numerosdeproyectos                -0.142970          0.349333
# horasmensualespromedio            -0.020048          0.339742
# tiempoenlaempresa                 -0.100866          0.131591
# accidentedetrabajo                 0.058697         -0.007104
# abandono                          -0.388375          0.006567
# promocionultimos5años              0.025605         -0.008684
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion              -0.142970               -0.020048
# ultimaevaluacion                  0.349333                0.339742
# numerosdeproyectos                1.000000                0.417211
# horasmensualespromedio            0.417211                1.000000
# tiempoenlaempresa                 0.196786                0.127755
# accidentedetrabajo               -0.004741               -0.010143
# abandono                          0.023787                0.071287
# promocionultimos5años            -0.006064               -0.003544
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion             -0.100866            0.058697 -0.388375
# ultimaevaluacion                 0.131591           -0.007104  0.006567
# numerosdeproyectos               0.196786           -0.004741  0.023787
# horasmensualespromedio           0.127755           -0.010143  0.071287
# tiempoenlaempresa                1.000000            0.002120  0.144822
# accidentedetrabajo               0.002120            1.000000 -0.154622
# abandono                         0.144822           -0.154622  1.000000
# promocionultimos5años            0.067433            0.039245 -0.061788
#
#                         promocionultimos5años
# niveldesatisfaccion                  0.025605
# ultimaevaluacion                    -0.008684
# numerosdeproyectos                  -0.006064
# horasmensualespromedio              -0.003544
# tiempoenlaempresa                    0.067433
# accidentedetrabajo                   0.039245
# abandono                            -0.061788
# promocionultimos5años                1.000000

# %%
plt.figure(figsize=(8,7))
sns.heatmap(pearson,
            annot=True,
            linewidths=.5)

plt.show()

# %% [markdown]
# <p align="justify">
# Un valor positivo grande (cercano a 1) indica una fuerte correlación positiva, es decir, si el valor de una de las variables aumenta, el valor de la otra variable aumenta también.
# <BR><BR>
# Un valor negativo grande (cercano a -1) indica una fuerte correlación negativa, es decir, que el valor de una de las variables disminuye al aumentar el de la otra y viceversa.
# <BR><BR>
# Un valor cercano a 0 (tanto positivo como negativo) indica la ausencia de cualquier correlación entre las dos variables, y por lo tanto esas variables son independientes entre sí.

# %% [markdown]
#  ## **<font color="#07a8ed">Ordenando los valores de la matriz de correlación</font>**

# %%
orden = pearson.unstack()

# %%
print(orden)
# Out:
# niveldesatisfaccion    niveldesatisfaccion       1.000000
#                        ultimaevaluacion          0.105021
#                        numerosdeproyectos       -0.142970
#                        horasmensualespromedio   -0.020048
#                        tiempoenlaempresa        -0.100866
#                                                    ...
# promocionultimos5años  horasmensualespromedio   -0.003544
#                        tiempoenlaempresa         0.067433
#                        accidentedetrabajo        0.039245
#                        abandono                 -0.061788
#                        promocionultimos5años     1.000000
# Length: 64, dtype: float64

# %%
orden = orden.sort_values()

# %%
print(orden)
# Out:
# abandono                niveldesatisfaccion      -0.388375
# niveldesatisfaccion     abandono                 -0.388375
# abandono                accidentedetrabajo       -0.154622
# accidentedetrabajo      abandono                 -0.154622
# niveldesatisfaccion     numerosdeproyectos       -0.142970
#                                                     ...
# horasmensualespromedio  horasmensualespromedio    1.000000
# numerosdeproyectos      numerosdeproyectos        1.000000
# ultimaevaluacion        ultimaevaluacion          1.000000
# abandono                abandono                  1.000000
# promocionultimos5años   promocionultimos5años     1.000000
# Length: 64, dtype: float64

# %% [markdown]
#  ### **<font color="#07a8ed">Viendo los valores negativos</font>**

# %%
negativos = orden[orden < 0]

# %%
print(negativos)
# Out:
# abandono                niveldesatisfaccion      -0.388375
# niveldesatisfaccion     abandono                 -0.388375
# abandono                accidentedetrabajo       -0.154622
# accidentedetrabajo      abandono                 -0.154622
# niveldesatisfaccion     numerosdeproyectos       -0.142970
# numerosdeproyectos      niveldesatisfaccion      -0.142970
# niveldesatisfaccion     tiempoenlaempresa        -0.100866
# tiempoenlaempresa       niveldesatisfaccion      -0.100866
# abandono                promocionultimos5años    -0.061788
# promocionultimos5años   abandono                 -0.061788
# horasmensualespromedio  niveldesatisfaccion      -0.020048
# niveldesatisfaccion     horasmensualespromedio   -0.020048
# horasmensualespromedio  accidentedetrabajo       -0.010143
# accidentedetrabajo      horasmensualespromedio   -0.010143
# ultimaevaluacion        promocionultimos5años    -0.008684
# promocionultimos5años   ultimaevaluacion         -0.008684
# accidentedetrabajo      ultimaevaluacion         -0.007104
# ultimaevaluacion        accidentedetrabajo       -0.007104
# promocionultimos5años   numerosdeproyectos       -0.006064
# numerosdeproyectos      promocionultimos5años    -0.006064
# accidentedetrabajo      numerosdeproyectos       -0.004741
# numerosdeproyectos      accidentedetrabajo       -0.004741
# horasmensualespromedio  promocionultimos5años    -0.003544
# promocionultimos5años   horasmensualespromedio   -0.003544
# dtype: float64

# %% [markdown]
#  ### **<font color="#07a8ed">Viendo los valores positivos</font>**

# %% [markdown]
# <p align="justify">
# Elegir variables fuertemente relacionadas. Es decir, se filtran las variables cuyos valores de coeficiente de correlación sean mayores de 0,4.

# %%
positivos = orden[orden > 0.4]

# %%
print(positivos)
# Out:
# horasmensualespromedio  numerosdeproyectos        0.417211
# numerosdeproyectos      horasmensualespromedio    0.417211
# niveldesatisfaccion     niveldesatisfaccion       1.000000
# accidentedetrabajo      accidentedetrabajo        1.000000
# tiempoenlaempresa       tiempoenlaempresa         1.000000
# horasmensualespromedio  horasmensualespromedio    1.000000
# numerosdeproyectos      numerosdeproyectos        1.000000
# ultimaevaluacion        ultimaevaluacion          1.000000
# abandono                abandono                  1.000000
# promocionultimos5años   promocionultimos5años     1.000000
# dtype: float64

# %% [markdown]
# ## **<font color="#07a8ed">Estilo en el DataFrame - Matriz en Pandas</font>**

# %%
pearson
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.105021
# ultimaevaluacion                   0.105021          1.000000
# numerosdeproyectos                -0.142970          0.349333
# horasmensualespromedio            -0.020048          0.339742
# tiempoenlaempresa                 -0.100866          0.131591
# accidentedetrabajo                 0.058697         -0.007104
# abandono                          -0.388375          0.006567
# promocionultimos5años              0.025605         -0.008684
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion              -0.142970               -0.020048
# ultimaevaluacion                  0.349333                0.339742
# numerosdeproyectos                1.000000                0.417211
# horasmensualespromedio            0.417211                1.000000
# tiempoenlaempresa                 0.196786                0.127755
# accidentedetrabajo               -0.004741               -0.010143
# abandono                          0.023787                0.071287
# promocionultimos5años            -0.006064               -0.003544
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion             -0.100866            0.058697 -0.388375
# ultimaevaluacion                 0.131591           -0.007104  0.006567
# numerosdeproyectos               0.196786           -0.004741  0.023787
# horasmensualespromedio           0.127755           -0.010143  0.071287
# tiempoenlaempresa                1.000000            0.002120  0.144822
# accidentedetrabajo               0.002120            1.000000 -0.154622
# abandono                         0.144822           -0.154622  1.000000
# promocionultimos5años            0.067433            0.039245 -0.061788
#
#                         promocionultimos5años
# niveldesatisfaccion                  0.025605
# ultimaevaluacion                    -0.008684
# numerosdeproyectos                  -0.006064
# horasmensualespromedio              -0.003544
# tiempoenlaempresa                    0.067433
# accidentedetrabajo                   0.039245
# abandono                            -0.061788
# promocionultimos5años                1.000000

# %%
pearson.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_dc7d7_row0_col0, #T_dc7d7_row1_col1, #T_dc7d7_row2_col2, #T_dc7d7_row3_col3, #T_dc7d7_row4_col4, #T_dc7d7_row5_col5, #T_dc7d7_row6_col6, #T_dc7d7_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc7d7_row0_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_dc7d7_row0_col2, #T_dc7d7_row0_col3, #T_dc7d7_row0_col4, #T_dc7d7_row0_col6, #T_dc7d7_row5_col1, #T_dc7d7_row6_col0, #T_dc7d7_row6_col5, #T_dc7d7_row6_col7, #T_dc7d7_row7_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc7d7_row0_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dc7d7_row0_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_dc7d7_row1_col0, #T_dc7d7_row1_col3, #T_dc7d7_row2_col1 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_dc7d7_row1_col2 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_dc7d7_row1_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dc7d7_row1_col5, #T_dc7d7_row3_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_dc7d7_row1_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dc7d7_row1_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_dc7d7_row2_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dc7d7_row2_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_dc7d7_row2_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_dc7d7_row2_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_dc7d7_row2_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_dc7d7_row2_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_dc7d7_row3_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_dc7d7_row3_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_dc7d7_row3_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_dc7d7_row3_col4, #T_dc7d7_row4_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_dc7d7_row3_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_dc7d7_row3_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dc7d7_row4_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_dc7d7_row4_col2, #T_dc7d7_row7_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_dc7d7_row4_col3, #T_dc7d7_row6_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_dc7d7_row4_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_dc7d7_row4_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_dc7d7_row4_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_dc7d7_row5_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_dc7d7_row5_col2, #T_dc7d7_row7_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_dc7d7_row5_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_dc7d7_row5_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_dc7d7_row5_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_dc7d7_row5_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_dc7d7_row6_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_dc7d7_row6_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_dc7d7_row6_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_dc7d7_row7_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_dc7d7_row7_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_dc7d7_row7_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_dc7d7_row7_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# </style>
# <table id="T_dc7d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc7d7_level0_col0" class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th id="T_dc7d7_level0_col1" class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th id="T_dc7d7_level0_col2" class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th id="T_dc7d7_level0_col3" class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th id="T_dc7d7_level0_col4" class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th id="T_dc7d7_level0_col5" class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th id="T_dc7d7_level0_col6" class="col_heading level0 col6" >abandono</th>
#       <th id="T_dc7d7_level0_col7" class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc7d7_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_dc7d7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dc7d7_row0_col1" class="data row0 col1" >0.105021</td>
#       <td id="T_dc7d7_row0_col2" class="data row0 col2" >-0.142970</td>
#       <td id="T_dc7d7_row0_col3" class="data row0 col3" >-0.020048</td>
#       <td id="T_dc7d7_row0_col4" class="data row0 col4" >-0.100866</td>
#       <td id="T_dc7d7_row0_col5" class="data row0 col5" >0.058697</td>
#       <td id="T_dc7d7_row0_col6" class="data row0 col6" >-0.388375</td>
#       <td id="T_dc7d7_row0_col7" class="data row0 col7" >0.025605</td>
#     </tr>
#     <tr>
#       <th id="T_dc7d7_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_dc7d7_row1_col0" class="data row1 col0" >0.105021</td>
#       <td id="T_dc7d7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dc7d7_row1_col2" class="data row1 col2" >0.349333</td>
#       <td id="T_dc7d7_row1_col3" class="data row1 col3" >0.339742</td>
#       <td id="T_dc7d7_row1_col4" class="data row1 col4" >0.131591</td>
#       <td id="T_dc7d7_row1_col5" class="data row1 col5" >-0.007104</td>
#       <td id="T_dc7d7_row1_col6" class="data row1 col6" >0.006567</td>
#       <td id="T_dc7d7_row1_col7" class="data row1 col7" >-0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_dc7d7_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_dc7d7_row2_col0" class="data row2 col0" >-0.142970</td>
#       <td id="T_dc7d7_row2_col1" class="data row2 col1" >0.349333</td>
#       <td id="T_dc7d7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_dc7d7_row2_col3" class="data row2 col3" >0.417211</td>
#       <td id="T_dc7d7_row2_col4" class="data row2 col4" >0.196786</td>
#       <td id="T_dc7d7_row2_col5" class="data row2 col5" >-0.004741</td>
#       <td id="T_dc7d7_row2_col6" class="data row2 col6" >0.023787</td>
#       <td id="T_dc7d7_row2_col7" class="data row2 col7" >-0.006064</td>
#     </tr>
#     <tr>
#       <th id="T_dc7d7_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_dc7d7_row3_col0" class="data row3 col0" >-0.020048</td>
#       <td id="T_dc7d7_row3_col1" class="data row3 col1" >0.339742</td>
#       <td id="T_dc7d7_row3_col2" class="data row3 col2" >0.417211</td>
#       <td id="T_dc7d7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_dc7d7_row3_col4" class="data row3 col4" >0.127755</td>
#       <td id="T_dc7d7_row3_col5" class="data row3 col5" >-0.010143</td>
#       <td id="T_dc7d7_row3_col6" class="data row3 col6" >0.071287</td>
#       <td id="T_dc7d7_row3_col7" class="data row3 col7" >-0.003544</td>
#     </tr>
#     <tr>
#       <th id="T_dc7d7_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_dc7d7_row4_col0" class="data row4 col0" >-0.100866</td>
#       <td id="T_dc7d7_row4_col1" class="data row4 col1" >0.131591</td>
#       <td id="T_dc7d7_row4_col2" class="data row4 col2" >0.196786</td>
#       <td id="T_dc7d7_row4_col3" class="data row4 col3" >0.127755</td>
#       <td id="T_dc7d7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_dc7d7_row4_col5" class="data row4 col5" >0.002120</td>
#       <td id="T_dc7d7_row4_col6" class="data row4 col6" >0.144822</td>
#       <td id="T_dc7d7_row4_col7" class="data row4 col7" >0.067433</td>
#     </tr>
#     <tr>
#       <th id="T_dc7d7_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_dc7d7_row5_col0" class="data row5 col0" >0.058697</td>
#       <td id="T_dc7d7_row5_col1" class="data row5 col1" >-0.007104</td>
#       <td id="T_dc7d7_row5_col2" class="data row5 col2" >-0.004741</t

# %%
pearson.style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_b1177_row0_col0, #T_b1177_row1_col1, #T_b1177_row2_col2, #T_b1177_row3_col3, #T_b1177_row4_col4, #T_b1177_row5_col5, #T_b1177_row6_col6, #T_b1177_row7_col7 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_b1177_row0_col1 {
#   background-color: #46039f;
#   color: #f1f1f1;
# }
# #T_b1177_row0_col2, #T_b1177_row0_col3, #T_b1177_row0_col4, #T_b1177_row0_col6, #T_b1177_row5_col1, #T_b1177_row6_col0, #T_b1177_row6_col5, #T_b1177_row6_col7, #T_b1177_row7_col1 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_b1177_row0_col5 {
#   background-color: #6400a7;
#   color: #f1f1f1;
# }
# #T_b1177_row0_col7 {
#   background-color: #3a049a;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col0, #T_b1177_row1_col3, #T_b1177_row2_col1 {
#   background-color: #a21d9a;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col2 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col4 {
#   background-color: #6f00a8;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col5, #T_b1177_row3_col5 {
#   background-color: #4c02a1;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col6 {
#   background-color: #8a09a5;
#   color: #f1f1f1;
# }
# #T_b1177_row1_col7 {
#   background-color: #2a0593;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col0 {
#   background-color: #6100a7;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col3 {
#   background-color: #b83289;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col4 {
#   background-color: #8606a6;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col5 {
#   background-color: #4e02a2;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col6 {
#   background-color: #8e0ca4;
#   color: #f1f1f1;
# }
# #T_b1177_row2_col7 {
#   background-color: #2c0594;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col0 {
#   background-color: #8305a7;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col1 {
#   background-color: #a01a9c;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col2 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col4, #T_b1177_row4_col0 {
#   background-color: #6e00a8;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col6 {
#   background-color: #9a169f;
#   color: #f1f1f1;
# }
# #T_b1177_row3_col7 {
#   background-color: #2e0595;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col1 {
#   background-color: #5102a3;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col2, #T_b1177_row7_col0 {
#   background-color: #8f0da4;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col3, #T_b1177_row6_col2 {
#   background-color: #5502a4;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col5 {
#   background-color: #5002a2;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col6 {
#   background-color: #ac2694;
#   color: #f1f1f1;
# }
# #T_b1177_row4_col7 {
#   background-color: #4b03a1;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col0 {
#   background-color: #9814a0;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col2, #T_b1177_row7_col2 {
#   background-color: #4903a0;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col3 {
#   background-color: #130789;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col4 {
#   background-color: #3e049c;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col6 {
#   background-color: #5e01a6;
#   color: #f1f1f1;
# }
# #T_b1177_row5_col7 {
#   background-color: #3f049c;
#   color: #f1f1f1;
# }
# #T_b1177_row6_col1 {
#   background-color: #16078a;
#   color: #f1f1f1;
# }
# #T_b1177_row6_col3 {
#   background-color: #3c049b;
#   color: #f1f1f1;
# }
# #T_b1177_row6_col4 {
#   background-color: #7401a8;
#   color: #f1f1f1;
# }
# #T_b1177_row7_col3 {
#   background-color: #19068c;
#   color: #f1f1f1;
# }
# #T_b1177_row7_col4 {
#   background-color: #5801a4;
#   color: #f1f1f1;
# }
# #T_b1177_row7_col5 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_b1177_row7_col6 {
#   background-color: #7801a8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1177" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1177_level0_col0" class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th id="T_b1177_level0_col1" class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th id="T_b1177_level0_col2" class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th id="T_b1177_level0_col3" class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th id="T_b1177_level0_col4" class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th id="T_b1177_level0_col5" class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th id="T_b1177_level0_col6" class="col_heading level0 col6" >abandono</th>
#       <th id="T_b1177_level0_col7" class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1177_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_b1177_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b1177_row0_col1" class="data row0 col1" >0.105021</td>
#       <td id="T_b1177_row0_col2" class="data row0 col2" >-0.142970</td>
#       <td id="T_b1177_row0_col3" class="data row0 col3" >-0.020048</td>
#       <td id="T_b1177_row0_col4" class="data row0 col4" >-0.100866</td>
#       <td id="T_b1177_row0_col5" class="data row0 col5" >0.058697</td>
#       <td id="T_b1177_row0_col6" class="data row0 col6" >-0.388375</td>
#       <td id="T_b1177_row0_col7" class="data row0 col7" >0.025605</td>
#     </tr>
#     <tr>
#       <th id="T_b1177_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_b1177_row1_col0" class="data row1 col0" >0.105021</td>
#       <td id="T_b1177_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b1177_row1_col2" class="data row1 col2" >0.349333</td>
#       <td id="T_b1177_row1_col3" class="data row1 col3" >0.339742</td>
#       <td id="T_b1177_row1_col4" class="data row1 col4" >0.131591</td>
#       <td id="T_b1177_row1_col5" class="data row1 col5" >-0.007104</td>
#       <td id="T_b1177_row1_col6" class="data row1 col6" >0.006567</td>
#       <td id="T_b1177_row1_col7" class="data row1 col7" >-0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_b1177_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_b1177_row2_col0" class="data row2 col0" >-0.142970</td>
#       <td id="T_b1177_row2_col1" class="data row2 col1" >0.349333</td>
#       <td id="T_b1177_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b1177_row2_col3" class="data row2 col3" >0.417211</td>
#       <td id="T_b1177_row2_col4" class="data row2 col4" >0.196786</td>
#       <td id="T_b1177_row2_col5" class="data row2 col5" >-0.004741</td>
#       <td id="T_b1177_row2_col6" class="data row2 col6" >0.023787</td>
#       <td id="T_b1177_row2_col7" class="data row2 col7" >-0.006064</td>
#     </tr>
#     <tr>
#       <th id="T_b1177_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_b1177_row3_col0" class="data row3 col0" >-0.020048</td>
#       <td id="T_b1177_row3_col1" class="data row3 col1" >0.339742</td>
#       <td id="T_b1177_row3_col2" class="data row3 col2" >0.417211</td>
#       <td id="T_b1177_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b1177_row3_col4" class="data row3 col4" >0.127755</td>
#       <td id="T_b1177_row3_col5" class="data row3 col5" >-0.010143</td>
#       <td id="T_b1177_row3_col6" class="data row3 col6" >0.071287</td>
#       <td id="T_b1177_row3_col7" class="data row3 col7" >-0.003544</td>
#     </tr>
#     <tr>
#       <th id="T_b1177_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_b1177_row4_col0" class="data row4 col0" >-0.100866</td>
#       <td id="T_b1177_row4_col1" class="data row4 col1" >0.131591</td>
#       <td id="T_b1177_row4_col2" class="data row4 col2" >0.196786</td>
#       <td id="T_b1177_row4_col3" class="data row4 col3" >0.127755</td>
#       <td id="T_b1177_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b1177_row4_col5" class="data row4 col5" >0.002120</td>
#       <td id="T_b1177_row4_col6" class="data row4 col6" >0.144822</td>
#       <td id="T_b1177_row4_col7" class="data row4 col7" >0.067433</td>
#     </tr>
#     <tr>
#       <th id="T_b1177_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_b1177_row5_col0" class="data row5 col0" >0.058697</td>
#       <td id="T_b1177_row5_col1" class="data row5 col1" >-0.007104</td>
#       <td id="T_b1177_row5_col2" class="data row5 col2" >-0.004741</t

# %%
pearson.style.background_gradient(cmap="viridis")
# Out:
# <style type="text/css">
# #T_8647b_row0_col0, #T_8647b_row1_col1, #T_8647b_row2_col2, #T_8647b_row3_col3, #T_8647b_row4_col4, #T_8647b_row5_col5, #T_8647b_row6_col6, #T_8647b_row7_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8647b_row0_col1 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_8647b_row0_col2, #T_8647b_row0_col3, #T_8647b_row0_col4, #T_8647b_row0_col6, #T_8647b_row5_col1, #T_8647b_row6_col0, #T_8647b_row6_col5, #T_8647b_row6_col7, #T_8647b_row7_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8647b_row0_col5 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_8647b_row0_col7 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col0, #T_8647b_row1_col3, #T_8647b_row2_col1 {
#   background-color: #2e6d8e;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col2 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col4 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col5, #T_8647b_row3_col5 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col6 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_8647b_row1_col7 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col0 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col3 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col4 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col5 {
#   background-color: #472e7c;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col6 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_8647b_row2_col7 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col0 {
#   background-color: #39558c;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col1 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col4, #T_8647b_row4_col0 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col6 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_8647b_row3_col7 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col1 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col2, #T_8647b_row7_col0 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col3, #T_8647b_row6_col2 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col5 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col6 {
#   background-color: #2b748e;
#   color: #f1f1f1;
# }
# #T_8647b_row4_col7 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col0 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col2, #T_8647b_row7_col2 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col3 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col4 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col6 {
#   background-color: #443a83;
#   color: #f1f1f1;
# }
# #T_8647b_row5_col7 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_8647b_row6_col1 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_8647b_row6_col3 {
#   background-color: #482071;
#   color: #f1f1f1;
# }
# #T_8647b_row6_col4 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_8647b_row7_col3 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_8647b_row7_col4 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_8647b_row7_col5 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# #T_8647b_row7_col6 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8647b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8647b_level0_col0" class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th id="T_8647b_level0_col1" class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th id="T_8647b_level0_col2" class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th id="T_8647b_level0_col3" class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th id="T_8647b_level0_col4" class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th id="T_8647b_level0_col5" class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th id="T_8647b_level0_col6" class="col_heading level0 col6" >abandono</th>
#       <th id="T_8647b_level0_col7" class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8647b_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_8647b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8647b_row0_col1" class="data row0 col1" >0.105021</td>
#       <td id="T_8647b_row0_col2" class="data row0 col2" >-0.142970</td>
#       <td id="T_8647b_row0_col3" class="data row0 col3" >-0.020048</td>
#       <td id="T_8647b_row0_col4" class="data row0 col4" >-0.100866</td>
#       <td id="T_8647b_row0_col5" class="data row0 col5" >0.058697</td>
#       <td id="T_8647b_row0_col6" class="data row0 col6" >-0.388375</td>
#       <td id="T_8647b_row0_col7" class="data row0 col7" >0.025605</td>
#     </tr>
#     <tr>
#       <th id="T_8647b_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_8647b_row1_col0" class="data row1 col0" >0.105021</td>
#       <td id="T_8647b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8647b_row1_col2" class="data row1 col2" >0.349333</td>
#       <td id="T_8647b_row1_col3" class="data row1 col3" >0.339742</td>
#       <td id="T_8647b_row1_col4" class="data row1 col4" >0.131591</td>
#       <td id="T_8647b_row1_col5" class="data row1 col5" >-0.007104</td>
#       <td id="T_8647b_row1_col6" class="data row1 col6" >0.006567</td>
#       <td id="T_8647b_row1_col7" class="data row1 col7" >-0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_8647b_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_8647b_row2_col0" class="data row2 col0" >-0.142970</td>
#       <td id="T_8647b_row2_col1" class="data row2 col1" >0.349333</td>
#       <td id="T_8647b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8647b_row2_col3" class="data row2 col3" >0.417211</td>
#       <td id="T_8647b_row2_col4" class="data row2 col4" >0.196786</td>
#       <td id="T_8647b_row2_col5" class="data row2 col5" >-0.004741</td>
#       <td id="T_8647b_row2_col6" class="data row2 col6" >0.023787</td>
#       <td id="T_8647b_row2_col7" class="data row2 col7" >-0.006064</td>
#     </tr>
#     <tr>
#       <th id="T_8647b_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_8647b_row3_col0" class="data row3 col0" >-0.020048</td>
#       <td id="T_8647b_row3_col1" class="data row3 col1" >0.339742</td>
#       <td id="T_8647b_row3_col2" class="data row3 col2" >0.417211</td>
#       <td id="T_8647b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8647b_row3_col4" class="data row3 col4" >0.127755</td>
#       <td id="T_8647b_row3_col5" class="data row3 col5" >-0.010143</td>
#       <td id="T_8647b_row3_col6" class="data row3 col6" >0.071287</td>
#       <td id="T_8647b_row3_col7" class="data row3 col7" >-0.003544</td>
#     </tr>
#     <tr>
#       <th id="T_8647b_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_8647b_row4_col0" class="data row4 col0" >-0.100866</td>
#       <td id="T_8647b_row4_col1" class="data row4 col1" >0.131591</td>
#       <td id="T_8647b_row4_col2" class="data row4 col2" >0.196786</td>
#       <td id="T_8647b_row4_col3" class="data row4 col3" >0.127755</td>
#       <td id="T_8647b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8647b_row4_col5" class="data row4 col5" >0.002120</td>
#       <td id="T_8647b_row4_col6" class="data row4 col6" >0.144822</td>
#       <td id="T_8647b_row4_col7" class="data row4 col7" >0.067433</td>
#     </tr>
#     <tr>
#       <th id="T_8647b_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_8647b_row5_col0" class="data row5 col0" >0.058697</td>
#       <td id="T_8647b_row5_col1" class="data row5 col1" >-0.007104</td>
#       <td id="T_8647b_row5_col2" class="data row5 col2" >-0.004741</t

# %%
pearson.style.background_gradient(cmap="copper")
# Out:
# <style type="text/css">
# #T_7796b_row0_col0, #T_7796b_row1_col1, #T_7796b_row2_col2, #T_7796b_row3_col3, #T_7796b_row4_col4, #T_7796b_row5_col5, #T_7796b_row6_col6, #T_7796b_row7_col7 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_7796b_row0_col1 {
#   background-color: #23160e;
#   color: #f1f1f1;
# }
# #T_7796b_row0_col2, #T_7796b_row0_col3, #T_7796b_row0_col4, #T_7796b_row0_col6, #T_7796b_row5_col1, #T_7796b_row6_col0, #T_7796b_row6_col5, #T_7796b_row6_col7, #T_7796b_row7_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7796b_row0_col5 {
#   background-color: #3a2517;
#   color: #f1f1f1;
# }
# #T_7796b_row0_col7 {
#   background-color: #1a100a;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col0, #T_7796b_row1_col3, #T_7796b_row2_col1 {
#   background-color: #6f462d;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col2 {
#   background-color: #885637;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col4 {
#   background-color: #432a1b;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col5, #T_7796b_row3_col5 {
#   background-color: #281910;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col6 {
#   background-color: #593824;
#   color: #f1f1f1;
# }
# #T_7796b_row1_col7 {
#   background-color: #0f0906;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col0 {
#   background-color: #382316;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col3 {
#   background-color: #875536;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col4 {
#   background-color: #553622;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col5 {
#   background-color: #291a10;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col6 {
#   background-color: #5d3b25;
#   color: #f1f1f1;
# }
# #T_7796b_row2_col7 {
#   background-color: #100a06;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col0 {
#   background-color: #533421;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col1 {
#   background-color: #6d452c;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col2 {
#   background-color: #9a623e;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col4, #T_7796b_row4_col0 {
#   background-color: #41291a;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col6 {
#   background-color: #68422a;
#   color: #f1f1f1;
# }
# #T_7796b_row3_col7 {
#   background-color: #110b07;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col1 {
#   background-color: #2b1b11;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col2, #T_7796b_row7_col0 {
#   background-color: #5e3b26;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col3, #T_7796b_row6_col2 {
#   background-color: #2e1d12;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col5 {
#   background-color: #2a1b11;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col6 {
#   background-color: #794d31;
#   color: #f1f1f1;
# }
# #T_7796b_row4_col7 {
#   background-color: #26180f;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col0 {
#   background-color: #654029;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col2, #T_7796b_row7_col2 {
#   background-color: #25170f;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col3 {
#   background-color: #020201;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col4 {
#   background-color: #1c120b;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col6 {
#   background-color: #352215;
#   color: #f1f1f1;
# }
# #T_7796b_row5_col7 {
#   background-color: #1e130c;
#   color: #f1f1f1;
# }
# #T_7796b_row6_col1 {
#   background-color: #040201;
#   color: #f1f1f1;
# }
# #T_7796b_row6_col3 {
#   background-color: #1b110b;
#   color: #f1f1f1;
# }
# #T_7796b_row6_col4 {
#   background-color: #462d1c;
#   color: #f1f1f1;
# }
# #T_7796b_row7_col3 {
#   background-color: #050302;
#   color: #f1f1f1;
# }
# #T_7796b_row7_col4 {
#   background-color: #301e13;
#   color: #f1f1f1;
# }
# #T_7796b_row7_col5 {
#   background-color: #342115;
#   color: #f1f1f1;
# }
# #T_7796b_row7_col6 {
#   background-color: #4a2f1e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7796b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7796b_level0_col0" class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th id="T_7796b_level0_col1" class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th id="T_7796b_level0_col2" class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th id="T_7796b_level0_col3" class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th id="T_7796b_level0_col4" class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th id="T_7796b_level0_col5" class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th id="T_7796b_level0_col6" class="col_heading level0 col6" >abandono</th>
#       <th id="T_7796b_level0_col7" class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7796b_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_7796b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7796b_row0_col1" class="data row0 col1" >0.105021</td>
#       <td id="T_7796b_row0_col2" class="data row0 col2" >-0.142970</td>
#       <td id="T_7796b_row0_col3" class="data row0 col3" >-0.020048</td>
#       <td id="T_7796b_row0_col4" class="data row0 col4" >-0.100866</td>
#       <td id="T_7796b_row0_col5" class="data row0 col5" >0.058697</td>
#       <td id="T_7796b_row0_col6" class="data row0 col6" >-0.388375</td>
#       <td id="T_7796b_row0_col7" class="data row0 col7" >0.025605</td>
#     </tr>
#     <tr>
#       <th id="T_7796b_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_7796b_row1_col0" class="data row1 col0" >0.105021</td>
#       <td id="T_7796b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7796b_row1_col2" class="data row1 col2" >0.349333</td>
#       <td id="T_7796b_row1_col3" class="data row1 col3" >0.339742</td>
#       <td id="T_7796b_row1_col4" class="data row1 col4" >0.131591</td>
#       <td id="T_7796b_row1_col5" class="data row1 col5" >-0.007104</td>
#       <td id="T_7796b_row1_col6" class="data row1 col6" >0.006567</td>
#       <td id="T_7796b_row1_col7" class="data row1 col7" >-0.008684</td>
#     </tr>
#     <tr>
#       <th id="T_7796b_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_7796b_row2_col0" class="data row2 col0" >-0.142970</td>
#       <td id="T_7796b_row2_col1" class="data row2 col1" >0.349333</td>
#       <td id="T_7796b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7796b_row2_col3" class="data row2 col3" >0.417211</td>
#       <td id="T_7796b_row2_col4" class="data row2 col4" >0.196786</td>
#       <td id="T_7796b_row2_col5" class="data row2 col5" >-0.004741</td>
#       <td id="T_7796b_row2_col6" class="data row2 col6" >0.023787</td>
#       <td id="T_7796b_row2_col7" class="data row2 col7" >-0.006064</td>
#     </tr>
#     <tr>
#       <th id="T_7796b_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_7796b_row3_col0" class="data row3 col0" >-0.020048</td>
#       <td id="T_7796b_row3_col1" class="data row3 col1" >0.339742</td>
#       <td id="T_7796b_row3_col2" class="data row3 col2" >0.417211</td>
#       <td id="T_7796b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7796b_row3_col4" class="data row3 col4" >0.127755</td>
#       <td id="T_7796b_row3_col5" class="data row3 col5" >-0.010143</td>
#       <td id="T_7796b_row3_col6" class="data row3 col6" >0.071287</td>
#       <td id="T_7796b_row3_col7" class="data row3 col7" >-0.003544</td>
#     </tr>
#     <tr>
#       <th id="T_7796b_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_7796b_row4_col0" class="data row4 col0" >-0.100866</td>
#       <td id="T_7796b_row4_col1" class="data row4 col1" >0.131591</td>
#       <td id="T_7796b_row4_col2" class="data row4 col2" >0.196786</td>
#       <td id="T_7796b_row4_col3" class="data row4 col3" >0.127755</td>
#       <td id="T_7796b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_7796b_row4_col5" class="data row4 col5" >0.002120</td>
#       <td id="T_7796b_row4_col6" class="data row4 col6" >0.144822</td>
#       <td id="T_7796b_row4_col7" class="data row4 col7" >0.067433</td>
#     </tr>
#     <tr>
#       <th id="T_7796b_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_7796b_row5_col0" class="data row5 col0" >0.058697</td>
#       <td id="T_7796b_row5_col1" class="data row5 col1" >-0.007104</td>
#       <td id="T_7796b_row5_col2" class="data row5 col2" >-0.004741</t

# %% [markdown]
#  ## **<font color="#07a8ed">Matriz de correlación - Método Spearman</font>**

# %%
spearman = analisis.corr(method="spearman", numeric_only =True)

# %%
spearman
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.162407
# ultimaevaluacion                   0.162407          1.000000
# numerosdeproyectos                 0.005786          0.350399
# horasmensualespromedio             0.062000          0.342061
# tiempoenlaempresa                 -0.139428          0.161154
# accidentedetrabajo                 0.056333         -0.005767
# abandono                          -0.365842         -0.002440
# promocionultimos5años              0.022306         -0.007167
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion               0.005786                0.062000
# ultimaevaluacion                  0.350399                0.342061
# numerosdeproyectos                1.000000                0.397855
# horasmensualespromedio            0.397855                1.000000
# tiempoenlaempresa                 0.251971                0.168750
# accidentedetrabajo                0.002328               -0.006063
# abandono                         -0.019544                0.046455
# promocionultimos5años            -0.002960               -0.002951
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion             -0.139428            0.056333 -0.365842
# ultimaevaluacion                 0.161154           -0.005767 -0.002440
# numerosdeproyectos               0.251971            0.002328 -0.019544
# horasmensualespromedio           0.168750           -0.006063  0.046455
# tiempoenlaempresa                1.000000           -0.027277  0.268876
# accidentedetrabajo              -0.027277            1.000000 -0.154622
# abandono                         0.268876           -0.154622  1.000000
# promocionultimos5años            0.035205            0.039245 -0.061788
#
#                         promocionultimos5años
# niveldesatisfaccion                  0.022306
# ultimaevaluacion                    -0.007167
# numerosdeproyectos                  -0.002960
# horasmensualespromedio              -0.002951
# tiempoenlaempresa                    0.035205
# accidentedetrabajo                   0.039245
# abandono                            -0.061788
# promocionultimos5años                1.000000

# %%
plt.figure(figsize=(9,8))
sns.heatmap(spearman,
            annot=True,
            linewidths=.5)

plt.show()

# %% [markdown]
# ## **<font color="#07a8ed">Matriz de correlación - Método Kendall</font>**

# %%
kendall = analisis.corr(method="kendall", numeric_only=True)

# %%
kendall
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                1.000000          0.113865
# ultimaevaluacion                   0.113865          1.000000
# numerosdeproyectos                 0.022077          0.266267
# horasmensualespromedio             0.051126          0.235374
# tiempoenlaempresa                 -0.110005          0.118842
# accidentedetrabajo                 0.046298         -0.004749
# abandono                          -0.300675         -0.002010
# promocionultimos5años              0.018332         -0.005903
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion               0.022077                0.051126
# ultimaevaluacion                  0.266267                0.235374
# numerosdeproyectos                1.000000                0.306987
# horasmensualespromedio            0.306987                1.000000
# tiempoenlaempresa                 0.195025                0.119466
# accidentedetrabajo                0.002096               -0.004966
# abandono                         -0.017601                0.038045
# promocionultimos5años            -0.002666               -0.002417
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion             -0.110005            0.046298 -0.300675
# ultimaevaluacion                 0.118842           -0.004749 -0.002010
# numerosdeproyectos               0.195025            0.002096 -0.017601
# horasmensualespromedio           0.119466           -0.004966  0.038045
# tiempoenlaempresa                1.000000           -0.024839  0.244851
# accidentedetrabajo              -0.024839            1.000000 -0.154622
# abandono                         0.244851           -0.154622  1.000000
# promocionultimos5años            0.032059            0.039245 -0.061788
#
#                         promocionultimos5años
# niveldesatisfaccion                  0.018332
# ultimaevaluacion                    -0.005903
# numerosdeproyectos                  -0.002666
# horasmensualespromedio              -0.002417
# tiempoenlaempresa                    0.032059
# accidentedetrabajo                   0.039245
# abandono                            -0.061788
# promocionultimos5años                1.000000

# %%
kendall.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_b742d_row0_col0, #T_b742d_row1_col1, #T_b742d_row2_col2, #T_b742d_row3_col3, #T_b742d_row4_col4, #T_b742d_row5_col5, #T_b742d_row6_col6, #T_b742d_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col3, #T_b742d_row2_col7, #T_b742d_row3_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col4, #T_b742d_row0_col6, #T_b742d_row5_col1, #T_b742d_row5_col3, #T_b742d_row6_col0, #T_b742d_row6_col1, #T_b742d_row6_col2, #T_b742d_row6_col5, #T_b742d_row6_col7, #T_b742d_row7_col1, #T_b742d_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b742d_row0_col7, #T_b742d_row5_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b742d_row1_col0, #T_b742d_row3_col2, #T_b742d_row6_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b742d_row1_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b742d_row1_col3, #T_b742d_row3_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b742d_row1_col4, #T_b742d_row3_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b742d_row1_col5, #T_b742d_row3_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b742d_row1_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b742d_row1_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b742d_row2_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b742d_row2_col1, #T_b742d_row3_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b742d_row2_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b742d_row2_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b742d_row2_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b742d_row2_col6 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b742d_row3_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b742d_row4_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b742d_row4_col1, #T_b742d_row4_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b742d_row4_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b742d_row4_col5, #T_b742d_row5_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b742d_row4_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b742d_row4_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b742d_row5_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b742d_row5_col2 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b742d_row5_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b742d_row6_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b742d_row7_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b742d_row7_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b742d_row7_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b742d_row7_col5 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b742d_row7_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b742d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b742d_level0_col0" class="col_heading level0 col0" >niveldesatisfaccion</th>
#       <th id="T_b742d_level0_col1" class="col_heading level0 col1" >ultimaevaluacion</th>
#       <th id="T_b742d_level0_col2" class="col_heading level0 col2" >numerosdeproyectos</th>
#       <th id="T_b742d_level0_col3" class="col_heading level0 col3" >horasmensualespromedio</th>
#       <th id="T_b742d_level0_col4" class="col_heading level0 col4" >tiempoenlaempresa</th>
#       <th id="T_b742d_level0_col5" class="col_heading level0 col5" >accidentedetrabajo</th>
#       <th id="T_b742d_level0_col6" class="col_heading level0 col6" >abandono</th>
#       <th id="T_b742d_level0_col7" class="col_heading level0 col7" >promocionultimos5años</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b742d_level0_row0" class="row_heading level0 row0" >niveldesatisfaccion</th>
#       <td id="T_b742d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b742d_row0_col1" class="data row0 col1" >0.113865</td>
#       <td id="T_b742d_row0_col2" class="data row0 col2" >0.022077</td>
#       <td id="T_b742d_row0_col3" class="data row0 col3" >0.051126</td>
#       <td id="T_b742d_row0_col4" class="data row0 col4" >-0.110005</td>
#       <td id="T_b742d_row0_col5" class="data row0 col5" >0.046298</td>
#       <td id="T_b742d_row0_col6" class="data row0 col6" >-0.300675</td>
#       <td id="T_b742d_row0_col7" class="data row0 col7" >0.018332</td>
#     </tr>
#     <tr>
#       <th id="T_b742d_level0_row1" class="row_heading level0 row1" >ultimaevaluacion</th>
#       <td id="T_b742d_row1_col0" class="data row1 col0" >0.113865</td>
#       <td id="T_b742d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b742d_row1_col2" class="data row1 col2" >0.266267</td>
#       <td id="T_b742d_row1_col3" class="data row1 col3" >0.235374</td>
#       <td id="T_b742d_row1_col4" class="data row1 col4" >0.118842</td>
#       <td id="T_b742d_row1_col5" class="data row1 col5" >-0.004749</td>
#       <td id="T_b742d_row1_col6" class="data row1 col6" >-0.002010</td>
#       <td id="T_b742d_row1_col7" class="data row1 col7" >-0.005903</td>
#     </tr>
#     <tr>
#       <th id="T_b742d_level0_row2" class="row_heading level0 row2" >numerosdeproyectos</th>
#       <td id="T_b742d_row2_col0" class="data row2 col0" >0.022077</td>
#       <td id="T_b742d_row2_col1" class="data row2 col1" >0.266267</td>
#       <td id="T_b742d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b742d_row2_col3" class="data row2 col3" >0.306987</td>
#       <td id="T_b742d_row2_col4" class="data row2 col4" >0.195025</td>
#       <td id="T_b742d_row2_col5" class="data row2 col5" >0.002096</td>
#       <td id="T_b742d_row2_col6" class="data row2 col6" >-0.017601</td>
#       <td id="T_b742d_row2_col7" class="data row2 col7" >-0.002666</td>
#     </tr>
#     <tr>
#       <th id="T_b742d_level0_row3" class="row_heading level0 row3" >horasmensualespromedio</th>
#       <td id="T_b742d_row3_col0" class="data row3 col0" >0.051126</td>
#       <td id="T_b742d_row3_col1" class="data row3 col1" >0.235374</td>
#       <td id="T_b742d_row3_col2" class="data row3 col2" >0.306987</td>
#       <td id="T_b742d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b742d_row3_col4" class="data row3 col4" >0.119466</td>
#       <td id="T_b742d_row3_col5" class="data row3 col5" >-0.004966</td>
#       <td id="T_b742d_row3_col6" class="data row3 col6" >0.038045</td>
#       <td id="T_b742d_row3_col7" class="data row3 col7" >-0.002417</td>
#     </tr>
#     <tr>
#       <th id="T_b742d_level0_row4" class="row_heading level0 row4" >tiempoenlaempresa</th>
#       <td id="T_b742d_row4_col0" class="data row4 col0" >-0.110005</td>
#       <td id="T_b742d_row4_col1" class="data row4 col1" >0.118842</td>
#       <td id="T_b742d_row4_col2" class="data row4 col2" >0.195025</td>
#       <td id="T_b742d_row4_col3" class="data row4 col3" >0.119466</td>
#       <td id="T_b742d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b742d_row4_col5" class="data row4 col5" >-0.024839</td>
#       <td id="T_b742d_row4_col6" class="data row4 col6" >0.244851</td>
#       <td id="T_b742d_row4_col7" class="data row4 col7" >0.032059</td>
#     </tr>
#     <tr>
#       <th id="T_b742d_level0_row5" class="row_heading level0 row5" >accidentedetrabajo</th>
#       <td id="T_b742d_row5_col0" class="data row5 col0" >0.046298</td>
#       <td id="T_b742d_row5_col1" class="data row5 col1" >-0.004749</td>
#       <td id="T_b742d_row5_col2" class="data row5 col2" >0.002096</td>
#       <td id="T_b742d_row5_col3" class="data row5 col3" >-0.004966</td>
#       <td id="T_b742d_row5_col4" class="data row5 col4" >-0.024839</td>
#       <td id="T_b742d_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b742d_row5_col6" class="data row5 col6" >-0.154622</td>
#       <td id=

# %%
plt.figure(figsize=(9,8))
sns.heatmap(kendall,
            annot=True,
            linewidths=.5)

plt.show()

# %%
pearson == kendall
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    True             False
# ultimaevaluacion                      False              True
# numerosdeproyectos                    False             False
# horasmensualespromedio                False             False
# tiempoenlaempresa                     False             False
# accidentedetrabajo                    False             False
# abandono                              False             False
# promocionultimos5años                 False             False
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                  False                   False
# ultimaevaluacion                     False                   False
# numerosdeproyectos                    True                   False
# horasmensualespromedio               False                    True
# tiempoenlaempresa                    False                   False
# accidentedetrabajo                   False                   False
# abandono                             False                   False
# promocionultimos5años                False                   False
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 False               False     False
# ultimaevaluacion                    False               False     False
# numerosdeproyectos                  False               False     False
# horasmensualespromedio              False               False     False
# tiempoenlaempresa                    True               False     False
# accidentedetrabajo                  False                True     False
# abandono                            False               False      True
# promocionultimos5años               False               False     False
#
#                         promocionultimos5años
# niveldesatisfaccion                     False
# ultimaevaluacion                        False
# numerosdeproyectos                      False
# horasmensualespromedio                  False
# tiempoenlaempresa                       False
# accidentedetrabajo                      False
# abandono                                False
# promocionultimos5años                    True

# %%
pearson == spearman
# Out:
#                         niveldesatisfaccion  ultimaevaluacion  \
# niveldesatisfaccion                    True             False
# ultimaevaluacion                      False              True
# numerosdeproyectos                    False             False
# horasmensualespromedio                False             False
# tiempoenlaempresa                     False             False
# accidentedetrabajo                    False             False
# abandono                              False             False
# promocionultimos5años                 False             False
#
#                         numerosdeproyectos  horasmensualespromedio  \
# niveldesatisfaccion                  False                   False
# ultimaevaluacion                     False                   False
# numerosdeproyectos                    True                   False
# horasmensualespromedio               False                    True
# tiempoenlaempresa                    False                   False
# accidentedetrabajo                   False                   False
# abandono                             False                   False
# promocionultimos5años                False                   False
#
#                         tiempoenlaempresa  accidentedetrabajo  abandono  \
# niveldesatisfaccion                 False               False     False
# ultimaevaluacion                    False               False     False
# numerosdeproyectos                  False               False     False
# horasmensualespromedio              False               False     False
# tiempoenlaempresa                    True               False     False
# accidentedetrabajo                  False                True     False
# abandono                            False               False      True
# promocionultimos5años               False               False     False
#
#                         promocionultimos5años
# niveldesatisfaccion                     False
# ultimaevaluacion                        False
# numerosdeproyectos                      False
# horasmensualespromedio                  False
# tiempoenlaempresa                       False
# accidentedetrabajo                      False
# abandono                                False
# promocionultimos5años                    True

# %% [markdown]
# ## **<font color="#07a8ed">Matriz de correlación - Cual metodo usar?-Tarea para el alumno</font>**
